# %% [markdown]
# # OpenAI Agent + Query Engine Experimental Cookbook
# In this notebook, we try out the OpenAIAgent across a variety of query engine tools and datasets. We explore how OpenAIAgent can compare/replace existing workflows solved by our retrievers/query engines.
#
# Auto retrieval
# Joint SQL and vector search
# NOTE: Any Text-to-SQL application should be aware that executing arbitrary SQL queries can be a security risk. It is recommended to take precautions as needed, such as using restricted roles, read-only databases, sandboxing, etc.
#
# AutoRetrieval from a Vector Database
# Our existing "auto-retrieval" capabilities (in VectorIndexAutoRetriever) allow an LLM to infer the right query parameters for a vector database - including both the query string and metadata filter.
#
# Since the OpenAI Function API can infer function parameters, we explore its capabilities in performing auto-retrieval here.
#
#
#
# https://docs.llamaindex.ai/en/stable/examples/agent/openai_agent_query_cookbook/

# %%
# %pip install llama-index-agent-openai
# %pip install llama-index-llms-openai
# %pip install llama-index-readers-wikipedia
# %pip install llama-index-vector-stores-pinecone
# Out:
# Requirement already satisfied: llama-index-agent-openai in c:\code\github\llamaindex\venv\lib\site-packages (0.3.4)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-agent-openai) (0.11.20)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.9 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-agent-openai) (0.2.16)
# Requirement already satisfied: openai>=1.14.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-agent-openai) (1.52.2)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.10.10)
# Requirement already satisfied: dataclasses-json in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2024.9.0)
# Requirement already satisfied: httpx in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\code\github\llamaindex\venv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\code\github\llamaindex\venv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (0.6.1)
# Requirement already satisfied: sniffio in c:\code\github\llamaindex\venv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (4.0.3)
# Requirement already satisfied: idna>=2.8 in c:\code\github\llamaindex\venv\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\code\github\llamaindex\venv\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai) (1.2.2)
# Requirement already satisfied: certifi in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\code\github\llamaindex\venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.14.0)
# Requirement already satisfied: click in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.1.1)
# Requirement already satisfied: colorama in c:\code\github\llamaindex\venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\code\github\llamaindex\venv\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.23.0)
# Requirement already satisfied: packaging>=17.0 in c:\code\github\llamaindex\venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-openai in c:\code\github\llamaindex\venv\lib\site-packages (0.2.16)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.7 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-llms-openai) (0.11.20)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-llms-openai) (1.52.2)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.10.10)
# Requirement already satisfied: dataclasses-json in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.0)
# Requirement already satisfied: httpx in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\code\github\llamaindex\venv\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\code\github\llamaindex\venv\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (0.6.1)
# Requirement already satisfied: sniffio in c:\code\github\llamaindex\venv\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.0.3)
# Requirement already satisfied: idna>=2.8 in c:\code\github\llamaindex\venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\code\github\llamaindex\venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.2.2)
# Requirement already satisfied: certifi in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\code\github\llamaindex\venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: colorama in c:\code\github\llamaindex\venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\code\github\llamaindex\venv\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.23.0)
# Requirement already satisfied: packaging>=17.0 in c:\code\github\llamaindex\venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-readers-wikipedia
#   Downloading llama_index_readers_wikipedia-0.2.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-readers-wikipedia) (0.11.20)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.10.10)
# Requirement already satisfied: dataclasses-json in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2024.9.0)
# Requirement already satisfied: httpx in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.9.0)
# Requirement already satisfied: wrapt in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (4.0.3)
# Requirement already satisfied: click in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (8.1.7)
# Requirement already satisfied: joblib in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.1.1)
# Requirement already satisfied: colorama in c:\code\github\llamaindex\venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\code\github\llamaindex\venv\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (3.23.0)
# Requirement already satisfied: anyio in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.0.6)
# Requirement already satisfied: sniffio in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\code\github\llamaindex\venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\code\github\llamaindex\venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\code\github\llamaindex\venv\lib\site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-readers-wikipedia) (1.2.2)
# Downloading llama_index_readers_wikipedia-0.2.0-py3-none-any.whl (2.7 kB)
# Installing collected packages: llama-index-readers-wikipedia
# Successfully installed llama-index-readers-wikipedia-0.2.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-vector-stores-pinecone
#   Downloading llama_index_vector_stores_pinecone-0.2.1-py3-none-any.whl.metadata (667 bytes)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-vector-stores-pinecone) (0.11.20)
# Collecting pinecone-client<6.0.0,>=3.2.2 (from llama-index-vector-stores-pinecone)
#   Downloading pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (3.10.10)
# Requirement already satisfied: dataclasses-json in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (2024.9.0)
# Requirement already satisfied: httpx in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (11.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.9.0)
# Requirement already satisfied: wrapt in c:\code\github\llamaindex\venv\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.16.0)
# Requirement already satisfied: certifi>=2019.11.17 in c:\code\github\llamaindex\venv\lib\site-packages (from pinecone-client<6.0.0,>=3.2.2->llama-index-vector-stores-pinecone) (2024.8.30)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client<6.0.0,>=3.2.2->llama-index-vector-stores-pinecone)
#   Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client<6.0.0,>=3.2.2->llama-index-vector-stores-pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: urllib3>=1.26.0 in c:\code\github\llamaindex\venv\lib\site-packages (from pinecone-client<6.0.0,>=3.2.2->llama-index-vector-stores-pinecone) (2.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\code\github\llamaindex\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (4.0.3)
# Requirement already satisfied: click in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (8.1.7)
# Requirement already satisfied: joblib in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\code\github\llamaindex\venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\code\github\llamaindex\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\code\github\llamaindex\venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in c:\code\github\llamaindex\venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (3.1.1)
# Requirement already satisfied: colorama in c:\code\github\llamaindex\venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\code\github\llamaindex\venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\code\github\llamaindex\venv\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (3.23.0)
# Requirement already satisfied: anyio in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.0.6)
# Requirement already satisfied: sniffio in c:\code\github\llamaindex\venv\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\code\github\llamaindex\venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\code\github\llamaindex\venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (24.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\code\github\llamaindex\venv\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\code\github\llamaindex\venv\lib\site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-vector-stores-pinecone) (1.2.2)
# Downloading llama_index_vector_stores_pinecone-0.2.1-py3-none-any.whl (7.0 kB)
# Downloading pinecone_client-5.0.1-py3-none-any.whl (244 kB)
# Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: pinecone-plugin-interface, pinecone-plugin-inference, pinecone-client, llama-index-vector-stores-pinecone
# Successfully installed llama-index-vector-stores-pinecone-0.2.1 pinecone-client-5.0.1 pinecone-plugin-inference-1.1.0 pinecone-plugin-interface-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
# NOTE: This is ONLY necessary in jupyter notebook.
# Details: Jupyter runs an event-loop behind the scenes.
#          This results in nested event-loops when we start an event-loop to make async queries.
#          This is normally not allowed, we use nest_asyncio to allow it for convenience.

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %% [markdown]
# # Global Models

# %%
from llama_index.core import Settings
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
Settings.llm = OpenAI(model="gpt-4o-mini")
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")

# %%
# Using the LlamaDebugHandler to print the trace of the sub questions
# captured by the SUB_QUESTION callback event type
from llama_index.core.callbacks import CallbackManager, LlamaDebugHandler

llama_debug = LlamaDebugHandler(print_trace_on_end=True)
callback_manager = CallbackManager([llama_debug])

Settings.callback_manager = callback_manager

# %%
import pinecone
api_key = os.environ["PINECONE_API_KEY"]

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key=api_key)
# Out:
# INFO:pinecone_plugin_interface.logging:Discovering subpackages in _NamespacePath(['c:\\Code\\Github\\LlamaIndex\\venv\\lib\\site-packages\\pinecone_plugins'])
# Discovering subpackages in _NamespacePath(['c:\\Code\\Github\\LlamaIndex\\venv\\lib\\site-packages\\pinecone_plugins'])
# INFO:pinecone_plugin_interface.logging:Looking for plugins in pinecone_plugins.inference
# Looking for plugins in pinecone_plugins.inference
# INFO:pinecone_plugin_interface.logging:Installing plugin inference into Pinecone
# Installing plugin inference into Pinecone

# %%
# dimensions are for text-embedding-ada-002
try:
    pc.create_index("quickstart-index", 
                dimension=1536, 
                metric="euclidean",
                spec=ServerlessSpec(cloud="aws",region="us-east-1"),
    )
except Exception:
    # most likely index already exists
    pass
# Out:
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"name":"quickstart-index","metric":"euclidean","dimension":1536,"status":{"ready":false,"state":"Initializing"},"host":"quickstart-index-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# response body: b'{"name":"quickstart-index","metric":"euclidean","dimension":1536,"status":{"ready":false,"state":"Initializing"},"host":"quickstart-index-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"name":"quickstart-index","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-index-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# response body: b'{"name":"quickstart-index","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-index-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'

# %%
pinecone_index = pc.Index("quickstart-index")
# Out:
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"name":"quickstart-index","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-index-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# response body: b'{"name":"quickstart-index","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-index-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'

# %%
# Optional: delete data in your pinecone index
pinecone_index.delete(deleteAll=True, namespace="test")
# Out:
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"code":5,"message":"Namespace not found","details":[]}'
# response body: b'{"code":5,"message":"Namespace not found","details":[]}'
# ---------------------------------------------------------------------------
# NotFoundException                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Optional: delete data in your pinecone index
# ----> 2 pinecone_index.delete(deleteAll=True, namespace="test")
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\utils\error_handling.py:11, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#       8 @wraps(func)
#       9 def inner_func(*args, **kwargs):
#      10     try:
# ---> 11         return func(*args, **kwargs)
#      12     except MaxRetryError as e:
#      13         if isinstance(e.reason, ProtocolError):
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\data\index.py:316, in Index.delete(self, ids, delete_all, namespace, filter, **kwargs)
#     306 _check_type = kwargs.pop("_check_type", False)
#     307 args_dict = self._parse_non_empty_args(
#     308     [
#     309         ("ids", ids),
#    (...)
#     313     ]
#     314 )
# --> 316 return self._vector_api.delete(
#     317     DeleteRequest(
#     318         **args_dict,
#     319         **{k: v for k, v in kwargs.items() if k not in _OPENAPI_ENDPOINT_PARAMS and v is not None},
#     320         _check_type=_check_type,
#     321     ),
#     322     **{k: v for k, v in kwargs.items() if k in _OPENAPI_ENDPOINT_PARAMS},
#     323 )
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\api_client.py:761, in Endpoint.__call__(self, *args, **kwargs)
#     750 def __call__(self, *args, **kwargs):
#     751     """This method is invoked when endpoints are called
#     752     Example:
#     753
#    (...)
#     759
#     760     """
# --> 761     return self.callable(self, *args, **kwargs)
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\data\api\data_plane_api.py:267, in DataPlaneApi.__init__.<locals>.__delete(self, delete_request, **kwargs)
#     265 kwargs["_host_index"] = kwargs.get("_host_index")
#     266 kwargs["delete_request"] = delete_request
# --> 267 return self.call_with_http_info(**kwargs)
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\api_client.py:819, in Endpoint.call_with_http_info(self, **kwargs)
#     816     header_list = self.api_client.select_header_content_type(content_type_headers_list)
#     817     params["header"]["Content-Type"] = header_list
# --> 819 return self.api_client.call_api(
#     820     self.settings["endpoint_path"],
#     821     self.settings["http_method"],
#     822     params["path"],
#     823     params["query"],
#     824     params["header"],
#     825     body=params["body"],
#     826     post_params=params["form"],
#     827     files=params["file"],
#     828     response_type=self.settings["response_type"],
#     829     auth_settings=self.settings["auth"],
#     830     async_req=kwargs["async_req"],
#     831     _check_type=kwargs["_check_return_type"],
#     832     _return_http_data_only=kwargs["_return_http_data_only"],
#     833     _preload_content=kwargs["_preload_content"],
#     834     _request_timeout=kwargs["_request_timeout"],
#     835     _host=_host,
#     836     collection_formats=params["collection_format"],
#     837 )
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\api_client.py:380, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     326 """Makes the HTTP request (synchronous) and returns deserialized data.
#     327
#     328 To make an async_req request, set the async_req parameter.
#    (...)
#     377     then the method will return the response directly.
#     378 """
#     379 if not async_req:
# --> 380     return self.__call_api(
#     381         resource_path,
#     382         method,
#     383         path_params,
#     384         query_params,
#     385         header_params,
#     386         body,
#     387         post_params,
#     388         files,
#     389         response_type,
#     390         auth_settings,
#     391         _return_http_data_only,
#     392         collection_formats,
#     393         _preload_content,
#     394         _request_timeout,
#     395         _host,
#     396         _check_type,
#     397     )
#     399 return self.pool.apply_async(
#     400     self.__call_api,
#     401     (
#    (...)
#     418     ),
#     419 )
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\api_client.py:187, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
# --> 187     raise e
#     189 self.last_response = response_data
#     191 return_data = response_data
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\api_client.py:175, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     171     url = _host + resource_path
#     173 try:
#     174     # perform request and return response
# --> 175     response_data = self.request(
#     176         method,
#     177         url,
#     178         query_params=query_params,
#     179         headers=header_params,
#     180         post_params=post_params,
#     181         body=body,
#     182         _preload_content=_preload_content,
#     183         _request_timeout=_request_timeout,
#     184     )
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\api_client.py:460, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     450     return self.rest_client.OPTIONS(
#     451         url,
#     452         query_params=query_params,
#    (...)
#     457         body=body,
#     458     )
#     459 elif method == "POST":
# --> 460     return self.rest_client.POST(
#     461         url,
#     462         query_params=query_params,
#     463         headers=headers,
#     464         post_params=post_params,
#     465         _preload_content=_preload_content,
#     466         _request_timeout=_request_timeout,
#     467         body=body,
#     468     )
#     469 elif method == "PUT":
#     470     return self.rest_client.PUT(
#     471         url,
#     472         query_params=query_params,
#    (...)
#     477         body=body,
#     478     )
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\rest.py:345, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     335 def POST(
#     336     self,
#     337     url,
#    (...)
#     343     _request_timeout=None,
#     344 ):
# --> 345     return self.request(
#     346         "POST",
#     347         url,
#     348         headers=headers,
#     349         query_params=query_params,
#     350         post_params=post_params,
#     351         _preload_content=_preload_content,
#     352         _request_timeout=_request_timeout,
#     353         body=body,
#     354     )
#
# File c:\Code\Github\LlamaIndex\venv\lib\site-packages\pinecone\core\openapi\shared\rest.py:274, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     271     raise ForbiddenException(http_resp=r)
#     273 if r.status == 404:
# --> 274     raise NotFoundException(http_resp=r)
#     276 if 500 <= r.status <= 599:
#     277     raise ServiceException(http_resp=r)
#
# NotFoundException: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Date': 'Fri, 01 Nov 2024 08:05:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '55', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '32', 'x-pinecone-request-id': '6380602307549067385', 'x-envoy-upstream-service-time': '32', 'server': 'envoy'})
# HTTP response body: {"code":5,"message":"Namespace not found","details":[]}

# %%
from llama_index.core import VectorStoreIndex, StorageContext
from llama_index.vector_stores.pinecone import PineconeVectorStore

# %%
from llama_index.core.schema import TextNode

nodes = [
    TextNode(
        text=(
            "Michael Jordan is a retired professional basketball player,"
            " widely regarded as one of the greatest basketball players of all"
            " time."
        ),
        metadata={
            "category": "Sports",
            "country": "United States",
            "gender": "male",
            "born": 1963,
        },
    ),
    TextNode(
        text=(
            "Angelina Jolie is an American actress, filmmaker, and"
            " humanitarian. She has received numerous awards for her acting"
            " and is known for her philanthropic work."
        ),
        metadata={
            "category": "Entertainment",
            "country": "United States",
            "gender": "female",
            "born": 1975,
        },
    ),
    TextNode(
        text=(
            "Elon Musk is a business magnate, industrial designer, and"
            " engineer. He is the founder, CEO, and lead designer of SpaceX,"
            " Tesla, Inc., Neuralink, and The Boring Company."
        ),
        metadata={
            "category": "Business",
            "country": "United States",
            "gender": "male",
            "born": 1971,
        },
    ),
    TextNode(
        text=(
            "Rihanna is a Barbadian singer, actress, and businesswoman. She"
            " has achieved significant success in the music industry and is"
            " known for her versatile musical style."
        ),
        metadata={
            "category": "Music",
            "country": "Barbados",
            "gender": "female",
            "born": 1988,
        },
    ),
    TextNode(
        text=(
            "Cristiano Ronaldo is a Portuguese professional footballer who is"
            " considered one of the greatest football players of all time. He"
            " has won numerous awards and set multiple records during his"
            " career."
        ),
        metadata={
            "category": "Sports",
            "country": "Portugal",
            "gender": "male",
            "born": 1985,
        },
    ),
]

# %%
vector_store = PineconeVectorStore(
    pinecone_index=pinecone_index, namespace="test"
)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# %%
index = VectorStoreIndex(nodes, storage_context=storage_context)
# Out:
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C5431750>, 'json_data': {'input': ['category: Sports country: United States gender: male born: 1963  Michael Jordan is a retired professional basketball player, widely regarded as one of the greatest basketball players of all time.', 'category: Entertainment country: United States gender: female born: 1975  Angelina Jolie is an American actress, filmmaker, and humanitarian. She has received numerous awards for her acting and is known for her philanthropic work.', 'category: Business country: United States gender: male born: 1971  Elon Musk is a business magnate, industrial designer, and engineer. He is the founder, CEO, and lead designer of SpaceX, Tesla, Inc., Neuralink, and The Boring Company.', 'category: Music country: Barbados gender: female born: 1988  Rihanna is a Barbadian singer, actress, and businesswoman. She has achieved significant success in the music industry and is known for her versatile musical style.', 'category: Sports country: Portugal gender: male born: 1985  Cristiano Ronaldo is a Portuguese professional footballer who is considered one of the greatest football players of all time. He has won numerous awards and set multiple records during his career.'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C5431750>, 'json_data': {'input': ['category: Sports country: United States gender: male born: 1963  Michael Jordan is a retired professional basketball player, widely regarded as one of the greatest basketball players of all time.', 'category: Entertainment country: United States gender: female born: 1975  Angelina Jolie is an American actress, filmmaker, and humanitarian. She has received numerous awards for her acting and is known for her philanthropic work.', 'category: Business country: United States gender: male born: 1971  Elon Musk is a business magnate, industrial designer, and engineer. He is the founder, CEO, and lead designer of SpaceX, Tesla, Inc., Neuralink, and The Boring Company.', 'category: Music country: Barbados gender: female born: 1988  Rihanna is a Barbadian singer, actress, and businesswoman. She has achieved significant success in the music industry and is known for her versatile musical style.', 'category: Sports country: Portugal gender: male born: 1985  Cristiano Ronaldo is a Portuguese professional footballer who is considered one of the greatest football players of all time. He has won numerous awards and set multiple records during his career.'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C539BEB0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C539BEB0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C539BE20>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C539BE20>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08
DEL'), ('content-encoding', 'gzip'), ('alt-svc', 'h3=":443"; ma=86400')])
# DEBUG:openai._base_client:request_id: req_ab0fc1596389ee5f7a3d784ebbcbee94
# request_id: req_ab0fc1596389ee5f7a3d784ebbcbee94
# Upserted vectors:   0%|          | 0/5 [00:00<?, ?it/s]
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"upsertedCount":5}'
# response body: b'{"upsertedCount":5}'
# Upserted vectors: 100%|██████████| 5/5 [00:02<00:00,  2.07it/s]
# **********
# Trace: index_construction
#     |_embedding -> 1.763578 seconds
# **********

# %% [markdown]
# # Define Function Tool
# Here we define the function interface, which is passed to OpenAI to perform auto-retrieval.
#
# We were not able to get OpenAI to work with nested pydantic objects or tuples as arguments, so we converted the metadata filter keys and values into lists for the function API to work with.

# %%
# define function tool
from llama_index.core.tools import FunctionTool
from llama_index.core.vector_stores import (
    VectorStoreInfo,
    MetadataInfo,
    MetadataFilter,
    MetadataFilters,
    FilterCondition,
    FilterOperator,
)
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine

from typing import List, Tuple, Any
from pydantic import BaseModel, Field

# hardcode top k for now
top_k = 3

# define vector store info describing schema of vector store
vector_store_info = VectorStoreInfo(
    content_info="brief biography of celebrities",
    metadata_info=[
        MetadataInfo(
            name="category",
            type="str",
            description=(
                "Category of the celebrity, one of [Sports, Entertainment,"
                " Business, Music]"
            ),
        ),
        MetadataInfo(
            name="country",
            type="str",
            description=(
                "Country of the celebrity, one of [United States, Barbados,"
                " Portugal]"
            ),
        ),
        MetadataInfo(
            name="gender",
            type="str",
            description=("Gender of the celebrity, one of [male, female]"),
        ),
        MetadataInfo(
            name="born",
            type="int",
            description=("Born year of the celebrity, could be any integer"),
        ),
    ],
)

# %%
# define pydantic model for auto-retrieval function
class AutoRetrieveModel(BaseModel):
    query: str = Field(..., description="natural language query string")
    filter_key_list: List[str] = Field(
        ..., description="List of metadata filter field names"
    )
    filter_value_list: List[Any] = Field(
        ...,
        description=(
            "List of metadata filter field values (corresponding to names"
            " specified in filter_key_list)"
        ),
    )
    filter_operator_list: List[str] = Field(
        ...,
        description=(
            "Metadata filters conditions (could be one of <, <=, >, >=, ==, !=)"
        ),
    )
    filter_condition: str = Field(
        ...,
        description=("Metadata filters condition values (could be AND or OR)"),
    )


description = f"""\
Use this tool to look up biographical information about celebrities.
The vector database schema is given below:
{vector_store_info.json()}
"""

# %% [markdown]
# # Define AutoRetrieve Functions

# %%
def auto_retrieve_fn(
    query: str,
    filter_key_list: List[str],
    filter_value_list: List[any],
    filter_operator_list: List[str],
    filter_condition: str,
):
    """Auto retrieval function.

    Performs auto-retrieval from a vector database, and then applies a set of filters.

    """
    query = query or "Query"

    metadata_filters = [
        MetadataFilter(key=k, value=v, operator=op)
        for k, v, op in zip(
            filter_key_list, filter_value_list, filter_operator_list
        )
    ]
    retriever = VectorIndexRetriever(
        index,
        filters=MetadataFilters(
            filters=metadata_filters, condition=filter_condition
        ),
        top_k=top_k,
    )
    query_engine = RetrieverQueryEngine.from_args(retriever)

    response = query_engine.query(query)
    return str(response)


auto_retrieve_tool = FunctionTool.from_defaults(
    fn=auto_retrieve_fn,
    name="celebrity_bios",
    description=description,
    fn_schema=AutoRetrieveModel,
)

# %% [markdown]
# # Initialize Agent

# %%
from llama_index.agent.openai import OpenAIAgent
from llama_index.llms.openai import OpenAI

agent = OpenAIAgent.from_tools(
    [auto_retrieve_tool],
    llm=OpenAI(temperature=0, model="gpt-4o-mini"),
    verbose=True,
)

# %%
response = agent.chat("Tell me about two celebrities from the United States. ")
# Out:
# Added user message to memory: Tell me about two celebrities from the United States.
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'celebrity_bios', 'description': 'Use this tool to look up biographical information about celebrities.\nThe vector database schema is given below:\n{"metadata_info":[{"name":"category","type":"str","description":"Category of the celebrity, one of [Sports, Entertainment, Business, Music]"},{"name":"country","type":"str","description":"Country of the celebrity, one of [United States, Barbados, Portugal]"},{"name":"gender","type":"str","description":"Gender of the celebrity, one of [male, female]"},{"name":"born","type":"int","description":"Born year of the celebrity, could be any integer"}],"content_info":"brief biography of celebrities"}\n', 'parameters': {'properties': {'query': {'description': 'natural language query string', 'title': 'Query', 'type': 'string'}, 'filter_key_list': {'description': 'List of metadata filter field names', 'items': {'type': 'string'}, 'title': 'Filter Key List', 'type': 'array'}, 'filter_value_list': {'description': 'List of metadata filter field values (corresponding to names specified in filter_key_list)', 'items': {}, 'title': 'Filter Value List', 'type': 'array'}, 'filter_operator_list': {'description': 'Metadata filters conditions (could be one of <, <=, >, >=, ==, !=)', 'items': {'type': 'string'}, 'title': 'Filter Operator List', 'type': 'array'}, 'filter_condition': {'description': 'Metadata filters condition values (could be AND or OR)', 'title': 'Filter Condition', 'type': 'string'}}, 'required': ['query', 'filter_key_list', 'filter_value_list', 'filter_operator_list', 'filter_condition'], 'type': 'object'}}}]}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'celebrity_bios', 'description': 'Use this tool to look up biographical information about celebrities.\nThe vector database schema is given below:\n{"metadata_info":[{"name":"category","type":"str","description":"Category of the celebrity, one of [Sports, Entertainment, Business, Music]"},{"name":"country","type":"str","description":"Country of the celebrity, one of [United States, Barbados, Portugal]"},{"name":"gender","type":"str","description":"Gender of the celebrity, one of [male, female]"},{"name":"born","type":"int","description":"Born year of the celebrity, could be any integer"}],"content_info":"brief biography of celebrities"}\n', 'parameters': {'properties': {'query': {'description': 'natural language query string', 'title': 'Query', 'type': 'string'}, 'filter_key_list': {'description': 'List of metadata filter field names', 'items': {'type': 'string'}, 'title': 'Filter Key List', 'type': 'array'}, 'filter_value_list': {'description': 'List of metadata filter field values (corresponding to names specified in filter_key_list)', 'items': {}, 'title': 'Filter Value List', 'type': 'array'}, 'filter_operator_list': {'description': 'Metadata filters conditions (could be one of <, <=, >, >=, ==, !=)', 'items': {'type': 'string'}, 'title': 'Filter Operator List', 'type': 'array'}, 'filter_condition': {'description': 'Metadata filters condition values (could be AND or OR)', 'title': 'Filter Condition', 'type': 'string'}}, 'required': ['query', 'filter_key_list', 'filter_value_list', 'filter_operator_list', 'filter_condition'], 'type': 'object'}}}]}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8413760>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8413760>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C83AEDC0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C83AEDC0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8413820>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8413820>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:13:47 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'3802'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'199968'), (b'x-ratelimit-reset-requests', b'8.64s'), (b'x-ratelimit-reset-tokens', b'9ms'), (b'x-request-id', b'req_7b816890ba4392067008e00e21b6ae78'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm
query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}
# Got output: Error: 1 validation error for MetadataFilters
# condition
#   Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/enum
# ========================
#
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'celebrity_bios', 'description': 'Use this tool to look up biographical information about celebrities.\nThe vector database schema is given below:\n{"metadata_info":[{"name":"category","type":"str","description":"Category of the celebrity, one of [Sports, Entertainment, Business, Music]"},{"name":"country","type":"str","description":"Country of the celebrity, one of [United States, Barbados, Portugal]"},{"name":"gender","type":"str","description":"Gender of the celebrity, one of [male, female]"},{"name":"born","type":"int","description":"Born year of the celebrity, could be any integer"}],"content_info":"brief biography of celebrities"}\n', 'parameters': {'properties': {'query': {'description': 'natural language query string', 'title': 'Query', 'type': 'string'}, 'filter_key_list': {'description': 'List of metadata filter field names', 'items': {'type': 'string'}, 'title': 'Filter Key List', 'type': 'array'}, 'filter_value_list': {'description': 'List of metadata filter field values (corresponding to names specified in filter_key_list)', 'items': {}, 'title': 'Filter Value List', 'type': 'array'}, 'filter_operator_list': {'description': 'Metadata filters conditions (could be one of <, <=, >, >=, ==, !=)', 'items': {'type': 'string'}, 'title': 'Filter Operator List', 'type': 'array'}, 'filter_condition': {'description': 'Metadata filters condition values (could be AND or OR)', 'title': 'Filter Condition', 'type': 'string'}}, 'required': ['query', 'filter_key_list', 'filter_value_list', 'filter_operator_list', 'filter_condition'], 'type': 'object'}}}]}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'celebrity_bios', 'description': 'Use this tool to look up biographical information about celebrities.\nThe vector database schema is given below:\n{"metadata_info":[{"name":"category","type":"str","description":"Category of the celebrity, one of [Sports, Entertainment, Business, Music]"},{"name":"country","type":"str","description":"Country of the celebrity, one of [United States, Barbados, Portugal]"},{"name":"gender","type":"str","description":"Gender of the celebrity, one of [male, female]"},{"name":"born","type":"int","description":"Born year of the celebrity, could be any integer"}],"content_info":"brief biography of celebrities"}\n', 'parameters': {'properties': {'query': {'description': 'natural language query string', 'title': 'Query', 'type': 'string'}, 'filter_key_list': {'description': 'List of metadata filter field names', 'items': {'type': 'string'}, 'title': 'Filter Key List', 'type': 'array'}, 'filter_value_list': {'description': 'List of metadata filter field values (corresponding to names specified in filter_key_list)', 'items': {}, 'title': 'Filter Value List', 'type': 'array'}, 'filter_operator_list': {'description': 'Metadata filters conditions (could be one of <, <=, >, >=, ==, !=)', 'items': {'type': 'string'}, 'title': 'Filter Operator List', 'type': 'array'}, 'filter_condition': {'description': 'Metadata filters condition values (could be AND or OR)', 'title': 'Filter Condition', 'type': 'string'}}, 'required': ['query', 'filter_key_list', 'filter_value_list', 'filter_operator_list', 'filter_condition'], 'type': 'object'}}}]}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:13:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1893'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'199862'), (b'x-ratelimit-reset-requests', b'13.064s'), (b'x-ratelimit-reset-tokens', b'41ms'), (b'x-request-id', b'req_6c992b6b41b8dfb958f3245256c2294c'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6d74ed681b69-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:13:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1893'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'199862'), (b'x-ratelimit-reset-requests', b'13.064s'), (b'x-ratelimit-reset-tokens', b'41ms'), (b'x-request-id', b'req_6c992b6b41b8dfb958f3245256c2294c'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6d74ed681b69-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:13:49 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1893', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'celebrity_bios', 'description': 'Use this tool to look up biographical information about celebrities.\nThe vector database schema is given below:\n{"metadata_info":[{"name":"category","type":"str","description":"Category of the celebrity, one of [Sports, Entertainment, Business, Music]"},{"name":"country","type":"str","description":"Country of the celebrity, one of [United States, Barbados, Portugal]"},{"name":"gender","type":"str","description":"Gender of the celebrity, one of [male, female]"},{"name":"born","type":"int","description":"Born ye ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'celebrity_bios', 'description': 'Use this tool to look up biographical information about celebrities.\nThe vector database schema is given below:\n{"metadata_info":[{"name":"category","type":"str","description":"Category of the celebrity, one of [Sports, Entertainment, Business, Music]"},{"name":"country","type":"str","description":"Country of the celebrity, one of [United States, Barbados, Portugal]"},{"name":"gender","type":"str","description":"Gender of the celebrity, one of [male, female]"},{"name":"born","type":"int","description":"Born year of the celebrity, could ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:05 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1730'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9993'), (b'x-ratelimit-remaining-tokens', b'199801'), (b'x-ratelimit-reset-requests', b'57.589s'), (b'x-ratelimit-reset-tokens', b'59ms'), (b'x-request-id', b'req_6555c96ae3e44023d13445d03d1ab7bf'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6dd88ec059a6-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:05 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1730'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9993'), (b'x-ratelimit-remaining-tokens', b'199801'), (b'x-ratelimit-reset-requests', b'57.589s'), (b'x-ratelimit-reset-tokens', b'59ms'), (b'x-request-id', b'req_6555c96ae3e44023d13445d03d1ab7bf'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6dd88ec059a6-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:05 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1730', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9993', 'x-ratelimit-remaining-tokens': '199801', 'x-ratelimit-reset-requests': '57.589s', 'x-ratelimit-reset-tokens': '59ms', 'x-request-id': 'req_6555c96ae3e44023d13445d03d1ab7bf', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6dd88ec059a6-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:05 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1730', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9993', 'x-ratelimit-remaining-tokens': '199801', 'x-ratelimit-reset-requests': '57.589s', 'x-ratelimit-reset-tokens': '59ms', 'x-request-id': 'req_6555c96ae3e44023d13445d03d1ab7bf', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6dd88ec059a6-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_6555c96ae3e44023d13445d03d1ab7bf
# request_id: req_6555c96ae3e44023d13445d03d1ab7bf
# **********
# Trace: chat
#     |_agent_step -> 23.07782 seconds
#       |_llm -> 4.974695 seconds
#       |_function_call -> 0.007692 seconds
#       |_function_call -> 0.0 seconds
#       |_llm -> 2.280333 seconds
#       |_function_call -> 4.450456 seconds
#       |_function_call -> 1.906223 seconds
#       |_llm -> 1.813886 seconds
#       |_function_call -> 2.492085 seconds
#       |_llm -> 1.39094 seconds
#       |_function_call -> 1.579516 seconds
#       |_llm -> 2.156973 seconds
# **********
# I found information about one celebrity from the United States:
#
# ### Angelina Jolie
# - **Born**: 1975
# - **Profession**: Actress, filmmaker, and humanitarian
# - **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.
#
# It seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!

# %%
print(str(response))
# Out:
# Here are two celebrities born after 1980:
#
# ### Rihanna
# - **Born**: 1988
# - **Profession**: Singer, actress, and businesswoman
# - **Notable Achievements**: Rihanna has achieved significant success in the music industry and is recognized for her versatile musical style.
#
# ### Cristiano Ronaldo
# - **Born**: 1985
# - **Profession**: Professional footballer
# - **Notable Achievements**: Cristiano Ronaldo is regarded as one of the greatest football players of all time. He has received numerous awards and set multiple records throughout his career.
#
# If you would like more information or details about other celebrities, feel free to ask!

# %%
response = agent.chat("Tell me about two celebrities born after 1980. ")
# Out:
# Added user message to memory: Tell me about two celebrities born after 1980.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'funct ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'celebrity_ ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'2130'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9992'), (b'x-ratelimit-remaining-tokens', b'199677'), (b'x-ratelimit-reset-requests', b'1m0.879s'), (b'x-ratelimit-reset-tokens', b'96ms'), (b'x-request-id', b'req_774226d72c7ad3a409df7912cc549d12'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6dfa0a2f59a6-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'2130'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9992'), (b'x-ratelimit-remaining-tokens', b'199677'), (b'x-ratelimit-reset-requests', b'1m0.879s'), (b'x-ratelimit-reset-tokens', b'96ms'), (b'x-request-id', b'req_774226d72c7ad3a409df7912cc549d12'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6dfa0a2f59a6-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:11 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '2130', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9992', 'x-ratelimit-remaining-tokens': '199677', 'x-ratelimit-reset-requests': '1m0.879s', 'x-ratelimit-reset-tokens': '96ms', 'x-request-id': 'req_774226d72c7ad3a409df7912cc549d12', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6dfa0a2f59a6-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:11 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '2130', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9992', 'x-ratelimit-remaining-tokens': '199677', 'x-ratelimit-reset-requests': '1m0.879s', 'x-ratelimit-reset-tokens': '96ms', 'x-request-id': 'req_774226d72c7ad3a409df7912cc549d12', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6dfa0a2f59a6-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_774226d72c7ad3a409df7912cc549d12
# request_id: req_774226d72c7ad3a409df7912cc549d12
# === Calling Function ===
# Calling function: celebrity_bios with args: {"query": "celebrity", "filter_key_list": ["born"], "filter_value_list": [1980], "filter_operator_list": [">"], "filter_condition": "or"}
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C84C5240>, 'json_data': {'input': ['celebrity'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C84C5240>, 'json_data': {'input': ['celebrity'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C4D28A90>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C4D28A90>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8468640>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8468640>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'64'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999997'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_6b1e5542303b575da63bd65fa086892b'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e0a3fec5999-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:11 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'64'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999997'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_6b1e5542303b575da63bd65fa086892b'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e0a3fec5999-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:11 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '64', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999997', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_6b1e5542303b575da63bd65fa086892b', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e0a3fec5999-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:11 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '64', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999997', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_6b1e5542303b575da63bd65fa086892b', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e0a3fec5999-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_6b1e5542303b575da63bd65fa086892b
# request_id: req_6b1e5542303b575da63bd65fa086892b
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{

# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}, {'role': 'user', 'content': 'Context information is below.\n---------------------\ncategory: Music\ncountry: Barbados\ngender: female\nborn: 1988\n\nRihanna is a Barbadian singer, actress, and businesswoman. She has achieved significant success in the music industry and is known for her versatile musical style.\n\ncategory: Sports\ncountry: Portugal\ngender: male\nborn: 1985\n\nCristiano Ronaldo is a Portuguese professional footballer who is considered one of the greatest football players of all time. He has won numerous awards and set multiple records during his career.\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: celebrity\nAnswer: '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}, {'role': 'user', 'content': 'Context information is below.\n---------------------\ncategory: Music\ncountry: Barbados\ngender: female\nborn: 1988\n\nRihanna is a Barbadian singer, actress, and businesswoman. She has achieved significant success in the music industry and is known for her versatile musical style.\n\ncategory: Sports\ncountry: Portugal\ngender: male\nborn: 1985\n\nCristiano Ronaldo is a Portuguese professional footballer who is considered one of the greatest football players of all time. He has won numerous awards and set multiple records during his career.\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: celebrity\nAnswer: '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C85BC580>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C85BC580>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8559240>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8559240>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:13 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'498'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9992'), (b'x-ratelimit-remaining-tokens', b'199730'), (b'x-ratelimit-reset-requests', b'1m6.089s'), (b'x-ratelimit-reset-tokens', b'81ms'), (b'x-request-id', b'req_3b1e697989605063811a963471f53312'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e0f0fb659db-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:13 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'498'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9992'), (b'x-ratelimit-remaining-tokens', b'199730'), (b'x-ratelimit-reset-requests', b'1m6.089s'), (b'x-ratelimit-reset-tokens', b'81ms'), (b'x-request-id', b'req_3b1e697989605063811a963471f53312'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e0f0fb659db-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:13 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '498', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9992', 'x-ratelimit-remaining-tokens': '199730', 'x-ratelimit-reset-requests': '1m6.089s', 'x-ratelimit-reset-tokens': '81ms', 'x-request-id': 'req_3b1e697989605063811a963471f53312', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e0f0fb659db-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:13 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '498', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9992', 'x-ratelimit-remaining-tokens': '199730', 'x-ratelimit-reset-requests': '1m6.089s', 'x-ratelimit-reset-tokens': '81ms', 'x-request-id': 'req_3b1e697989605063811a963471f53312', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e0f0fb659db-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_3b1e697989605063811a963471f53312
# request_id: req_3b1e697989605063811a963471f53312
# Got output: Rihanna and Cristiano Ronaldo are both notable celebrities in their respective fields of music and sports.
# ========================
#
# === Calling Function ===
# Calling function: celebrity_bios with args: {"query": "celebrity", "filter_key_list": ["born"], "filter_value_list": [1980], "filter_operator_list": [">"], "filter_condition": "or"}
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C84C4DC0>, 'json_data': {'input': ['celebrity'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C84C4DC0>, 'json_data': {'input': ['celebrity'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:14 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'72'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999997'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_2c495faeec277f84030dd27af7ee7f78'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e14cd505999-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:14 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'72'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999997'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_2c495faeec277f84030dd27af7ee7f78'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e14cd505999-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:14 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '72', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999997', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_2c495faeec277f84030dd27af7ee7f78', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e14cd505999-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:14 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '72', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999997', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_2c495faeec277f84030dd27af7ee7f78', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e14cd505999-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_2c495faeec277f84030dd27af7ee7f78
# request_id: req_2c495faeec277f84030dd27af7ee7f78
# ...
# DEBUG:openai._base_client:request_id: req_263b52a509c879d3ec7b41a7626c52cd
# request_id: req_263b52a509c879d3ec7b41a7626c52cd
# Got output: Cristiano Ronaldo is a Portuguese professional footballer, born in 1985, who is regarded as one of the greatest football players of all time. He has received numerous awards and set multiple records throughout his career.
# ========================
#
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_7dBmEd7fO1QkoPM1xFHMPpvq', 'function': {'arguments': '{ ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_7dBmEd7fO1QkoPM1xFHMPpvq', 'function': {'arguments': '{"query": "celebrity", "fil ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C855AEC0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C855AEC0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C83AEDC0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C83AEDC0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8559900>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C8559900>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:26 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'3170'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9988'), (b'x-ratelimit-remaining-tokens', b'199542'), (b'x-ratelimit-reset-requests', b'1m39.112s'), (b'x-ratelimit-reset-tokens', b'137ms'), (b'x-request-id', b'req_791615367143f42a1b0bfee95b3c9983'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e4ec9b38ad9-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:26 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'3170'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9988'), (b'x-ratelimit-remaining-tokens', b'199542'), (b'x-ratelimit-reset-requests', b'1m39.112s'), (b'x-ratelimit-reset-tokens', b'137ms'), (b'x-request-id', b'req_791615367143f42a1b0bfee95b3c9983'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6e4ec9b38ad9-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:26 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '3170', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9988', 'x-ratelimit-remaining-tokens': '199542', 'x-ratelimit-reset-requests': '1m39.112s', 'x-ratelimit-reset-tokens': '137ms', 'x-request-id': 'req_791615367143f42a1b0bfee95b3c9983', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e4ec9b38ad9-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:26 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '3170', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9988', 'x-ratelimit-remaining-tokens': '199542', 'x-ratelimit-reset-requests': '1m39.112s', 'x-ratelimit-reset-tokens': '137ms', 'x-request-id': 'req_791615367143f42a1b0bfee95b3c9983', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6e4ec9b38ad9-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_791615367143f42a1b0bfee95b3c9983
# request_id: req_791615367143f42a1b0bfee95b3c9983
# **********
# Trace: chat
#     |_agent_step -> 17.187484 seconds
#       |_llm -> 2.546307 seconds
#       |_function_call -> 1.767913 seconds
#       |_function_call -> 1.849483 seconds
#       |_llm -> 2.076597 seconds
#       |_function_call -> 3.41811 seconds
#       |_function_call -> 1.818731 seconds
#       |_llm -> 3.697343 seconds
# **********
# Here are two celebrities born after 1980:
#
# ### Rihanna
# - **Born**: 1988
# - **Profession**: Singer, actress, and businesswoman
# - **Notable Achievements**: Rihanna has achieved significant success in the music industry and is recognized for her versatile musical style.
#
# ### Cristiano Ronaldo
# - **Born**: 1985
# - **Profession**: Professional footballer
# - **Notable Achievements**: Cristiano Ronaldo is regarded as one of the greatest football players of all time. He has received numerous awards and set multiple records throughout his career.
#
# If you would like more information or details about other celebrities, feel free to ask!

# %%
print(str(response))

# %%
response = agent.chat(
    "Tell me about few celebrities under category business and born after 1950. "
)
# Out:
# Added user message to memory: Tell me about few celebrities under category business and born after 1950.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_7dBmEd7fO1QkoPM1xFHMPpvq', 'function': {'arguments': '{ ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_7dBmEd7fO1QkoPM1xFHMPpvq', 'function': {'arguments': '{"query": "celebrity", "fil ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C84DBC40>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C84DBC40>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C83AEDC0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C83AEDC0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C842B280>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C842B280>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:56 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1068'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9991'), (b'x-ratelimit-remaining-tokens', b'199363'), (b'x-ratelimit-reset-requests', b'1m15.328s'), (b'x-ratelimit-reset-tokens', b'190ms'), (b'x-request-id', b'req_642e9ab4fa6c3a6a6f43b5d54f944d84'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f19aa93549c-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:56 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1068'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9991'), (b'x-ratelimit-remaining-tokens', b'199363'), (b'x-ratelimit-reset-requests', b'1m15.328s'), (b'x-ratelimit-reset-tokens', b'190ms'), (b'x-request-id', b'req_642e9ab4fa6c3a6a6f43b5d54f944d84'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f19aa93549c-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:56 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1068', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9991', 'x-ratelimit-remaining-tokens': '199363', 'x-ratelimit-reset-requests': '1m15.328s', 'x-ratelimit-reset-tokens': '190ms', 'x-request-id': 'req_642e9ab4fa6c3a6a6f43b5d54f944d84', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6f19aa93549c-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:56 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1068', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9991', 'x-ratelimit-remaining-tokens': '199363', 'x-ratelimit-reset-requests': '1m15.328s', 'x-ratelimit-reset-tokens': '190ms', 'x-request-id': 'req_642e9ab4fa6c3a6a6f43b5d54f944d84', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6f19aa93549c-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_642e9ab4fa6c3a6a6f43b5d54f944d84
# request_id: req_642e9ab4fa6c3a6a6f43b5d54f944d84
# === Calling Function ===
# Calling function: celebrity_bios with args: {"query":"celebrity","filter_key_list":["category","born"],"filter_value_list":["Business",1950],"filter_operator_list":["==",">"],"filter_condition":"and"}
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C84C5BD0>, 'json_data': {'input': ['celebrity'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C84C5BD0>, 'json_data': {'input': ['celebrity'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C855AAD0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C855AAD0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C539B850>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C539B850>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:57 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'90'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999997'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_627517fa2afa41ad8893f5376fe32299'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f22d9bd91c2-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:57 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'90'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999997'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_627517fa2afa41ad8893f5376fe32299'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f22d9bd91c2-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:57 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '90', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999997', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_627517fa2afa41ad8893f5376fe32299', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6f22d9bd91c2-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14
Musk is a business magnate, industrial designer, and engineer. He is the founder, CEO, and lead designer of SpaceX, Tesla, Inc., Neuralink, and The Boring Company.\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: celebrity\nAnswer: '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}, {'role': 'user', 'content': 'Context information is below.\n---------------------\ncategory: Business\ncountry: United States\ngender: male\nborn: 1971\n\nElon Musk is a business magnate, industrial designer, and engineer. He is the founder, CEO, and lead designer of SpaceX, Tesla, Inc., Neuralink, and The Boring Company.\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: celebrity\nAnswer: '}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C865E050>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C865E050>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C53659C0>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C53659C0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:58 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'602'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9990'), (b'x-ratelimit-remaining-tokens', b'199792'), (b'x-ratelimit-reset-requests', b'1m21.182s'), (b'x-ratelimit-reset-tokens', b'62ms'), (b'x-request-id', b'req_cc59c0a5088d88444173423547c71f3d'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f2b2f615951-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:14:58 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'602'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9990'), (b'x-ratelimit-remaining-tokens', b'199792'), (b'x-ratelimit-reset-requests', b'1m21.182s'), (b'x-ratelimit-reset-tokens', b'62ms'), (b'x-request-id', b'req_cc59c0a5088d88444173423547c71f3d'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f2b2f615951-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:58 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '602', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9990', 'x-ratelimit-remaining-tokens': '199792', 'x-ratelimit-reset-requests': '1m21.182s', 'x-ratelimit-reset-tokens': '62ms', 'x-request-id': 'req_cc59c0a5088d88444173423547c71f3d', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6f2b2f615951-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:14:58 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '602', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9990', 'x-ratelimit-remaining-tokens': '199792', 'x-ratelimit-reset-requests': '1m21.182s', 'x-ratelimit-reset-tokens': '62ms', 'x-request-id': 'req_cc59c0a5088d88444173423547c71f3d', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6f2b2f615951-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_cc59c0a5088d88444173423547c71f3d
# request_id: req_cc59c0a5088d88444173423547c71f3d
# Got output: Elon Musk is a well-known celebrity, recognized for his significant contributions to various industries, including space exploration, electric vehicles, and technology.
# ========================
#
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_7dBmEd7fO1QkoPM1xFHMPpvq', 'function': {'arguments': '{ ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about two celebrities from the United States. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_ihJodUTZWVhTIRmWEPdWmUSD', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_104KVdQbH4BNm4M7bNRJMGsx', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "AND"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_ihJodUTZWVhTIRmWEPdWmUSD'}, {'role': 'tool', 'content': "Error: 1 validation error for MetadataFilters\ncondition\n  Input should be 'and' or 'or' [type=enum, input_value='AND', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.9/v/enum", 'name': 'celebrity_bios', 'tool_call_id': 'call_104KVdQbH4BNm4M7bNRJMGsx'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}, {'id': 'call_j6I0vYx87YIz8V9Q58FBK1C9', 'function': {'arguments': '{"query": "celebrity", "filter_key_list": ["country"], "filter_value_list": ["United States"], "filter_operator_list": ["=="], "filter_condition": "or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_E19cQ1tGDsBmQQjaXQRRHUa4'}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_j6I0vYx87YIz8V9Q58FBK1C9'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YKfedST3tyrUSxsVWZzLGJbt', 'function': {'arguments': '{"query":"Angelina Jolie","filter_key_list":[],"filter_value_list":[],"filter_operator_list":[],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie is an American actress, filmmaker, and humanitarian, born in 1975. She has received numerous awards for her acting and is recognized for her philanthropic efforts.', 'name': 'celebrity_bios', 'tool_call_id': 'call_YKfedST3tyrUSxsVWZzLGJbt'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_nyB72lPKYU90DjsYS3yprm18', 'function': {'arguments': '{"query":"celebrity","filter_key_list":["country"],"filter_value_list":["United States"],"filter_operator_list":["=="],"filter_condition":"or"}', 'name': 'celebrity_bios'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Angelina Jolie', 'name': 'celebrity_bios', 'tool_call_id': 'call_nyB72lPKYU90DjsYS3yprm18'}, {'role': 'assistant', 'content': 'I found information about one celebrity from the United States:\n\n### Angelina Jolie\n- **Born**: 1975\n- **Profession**: Actress, filmmaker, and humanitarian\n- **Notable Achievements**: Angelina Jolie has received numerous awards for her acting and is recognized for her philanthropic efforts.\n\nIt seems that the search returned only Angelina Jolie. If you would like to know about another celebrity or a specific category, please let me know!'}, {'role': 'user', 'content': 'Tell me about two celebrities born after 1980. '}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_7dBmEd7fO1QkoPM1xFHMPpvq', 'function': {'arguments': '{"query": "celebrity", "fil ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:15:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1829'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9989'), (b'x-ratelimit-remaining-tokens', b'199320'), (b'x-ratelimit-reset-requests', b'1m28.772s'), (b'x-ratelimit-reset-tokens', b'204ms'), (b'x-request-id', b'req_ff53b0f865672dad01b666d08d732121'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f31afef549c-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:15:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1829'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9989'), (b'x-ratelimit-remaining-tokens', b'199320'), (b'x-ratelimit-reset-requests', b'1m28.772s'), (b'x-ratelimit-reset-tokens', b'204ms'), (b'x-request-id', b'req_ff53b0f865672dad01b666d08d732121'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba6f31afef549c-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:15:00 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1829', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9989', 'x-ratelimit-remaining-tokens': '199320', 'x-ratelimit-reset-requests': '1m28.772s', 'x-ratelimit-reset-tokens': '204ms', 'x-request-id': 'req_ff53b0f865672dad01b666d08d732121', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6f31afef549c-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:15:00 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1829', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9989', 'x-ratelimit-remaining-tokens': '199320', 'x-ratelimit-reset-requests': '1m28.772s', 'x-ratelimit-reset-tokens': '204ms', 'x-request-id': 'req_ff53b0f865672dad01b666d08d732121', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba6f31afef549c-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_ff53b0f865672dad01b666d08d732121
# request_id: req_ff53b0f865672dad01b666d08d732121
# **********
# Trace: chat
#     |_agent_step -> 6.167955 seconds
#       |_llm -> 1.565383 seconds
#       |_function_call -> 2.347337 seconds
#       |_llm -> 2.247237 seconds
# **********

# %%
print(str(response))

# %% [markdown]
# # Joint Text-to-SQL and Semantic Search
# This is currently handled by our SQLAutoVectorQueryEngine.
#
# Let's try implementing this by giving our OpenAIAgent access to two query tools: SQL and Vector
#
# NOTE: Any Text-to-SQL application should be aware that executing arbitrary SQL queries can be a security risk. It is recommended to take precautions as needed, such as using restricted roles, read-only databases, sandboxing, etc.
#
#
# ## Load and Index Structured Data
# We load sample structured datapoints into a SQL db and index it.

# %%
from sqlalchemy import (
    create_engine,
    MetaData,
    Table,
    Column,
    String,
    Integer,
    select,
    column,
)
from llama_index.core import SQLDatabase
from llama_index.core.indices import SQLStructStoreIndex

engine = create_engine("sqlite:///:memory:", future=True)
metadata_obj = MetaData()

# %%
# create city SQL table
table_name = "city_stats"
city_stats_table = Table(
    table_name,
    metadata_obj,
    Column("city_name", String(16), primary_key=True),
    Column("population", Integer),
    Column("country", String(16), nullable=False),
)

metadata_obj.create_all(engine)

# %%
# print tables
metadata_obj.tables.keys()
# Out:
# dict_keys(['city_stats'])

# %%
from sqlalchemy import insert

rows = [
    {"city_name": "Toronto", "population": 2930000, "country": "Canada"},
    {"city_name": "Tokyo", "population": 13960000, "country": "Japan"},
    {"city_name": "Berlin", "population": 3645000, "country": "Germany"},
]
for row in rows:
    stmt = insert(city_stats_table).values(**row)
    with engine.begin() as connection:
        cursor = connection.execute(stmt)

# %%
with engine.connect() as connection:
    cursor = connection.exec_driver_sql("SELECT * FROM city_stats")
    print(cursor.fetchall())
# Out:
# [('Toronto', 2930000, 'Canada'), ('Tokyo', 13960000, 'Japan'), ('Berlin', 3645000, 'Germany')]

# %%
sql_database = SQLDatabase(engine, include_tables=["city_stats"])

# %%
from llama_index.core.query_engine import NLSQLTableQueryEngine

# %%
query_engine = NLSQLTableQueryEngine(
    sql_database=sql_database,
    tables=["city_stats"],
)

# %% [markdown]
# # Load and Index Unstructured Data
# We load unstructured data into a vector index backed by Pinecone

# %%
# install wikipedia python package
# !pip install wikipedia
# Out:
# Collecting wikipedia
#   Using cached wikipedia-1.4.0-py3-none-any.whl
# Requirement already satisfied: beautifulsoup4 in c:\code\github\llamaindex\venv\lib\site-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\code\github\llamaindex\venv\lib\site-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\code\github\llamaindex\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\code\github\llamaindex\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\code\github\llamaindex\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\code\github\llamaindex\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in c:\code\github\llamaindex\venv\lib\site-packages (from beautifulsoup4->wikipedia) (2.6)
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
from llama_index.readers.wikipedia import WikipediaReader
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex

# %%
cities = ["Toronto", "Berlin", "Tokyo"]
wiki_docs = WikipediaReader().load_data(pages=cities)

# %%
# define pinecone index
from pinecone import Pinecone, ServerlessSpec
import os

api_key = os.environ["PINECONE_API_KEY"]
pc = Pinecone(api_key=api_key)
# Out:
# INFO:pinecone_plugin_interface.logging:Discovering subpackages in _NamespacePath(['c:\\Code\\Github\\LlamaIndex\\venv\\lib\\site-packages\\pinecone_plugins'])
# Discovering subpackages in _NamespacePath(['c:\\Code\\Github\\LlamaIndex\\venv\\lib\\site-packages\\pinecone_plugins'])
# INFO:pinecone_plugin_interface.logging:Looking for plugins in pinecone_plugins.inference
# Looking for plugins in pinecone_plugins.inference
# INFO:pinecone_plugin_interface.logging:Installing plugin inference into Pinecone
# Installing plugin inference into Pinecone

# %%
# dimensions are for text-embedding-ada-002
try:
    pc.create_index("quickstart", 
                dimension=1536, 
                metric="euclidean",
                spec=ServerlessSpec(cloud="aws",region="us-east-1"),
    )
except Exception:
    # most likely index already exists
    pass
# Out:
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"name":"quickstart","metric":"euclidean","dimension":1536,"status":{"ready":false,"state":"Initializing"},"host":"quickstart-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# response body: b'{"name":"quickstart","metric":"euclidean","dimension":1536,"status":{"ready":false,"state":"Initializing"},"host":"quickstart-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"name":"quickstart","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# response body: b'{"name":"quickstart","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'

# %%
# vector_store = PineconeVectorStore(
#     pinecone_index=pinecone_index, namespace="test"
# )
# storage_context = StorageContext.from_defaults(vector_store=vector_store)

# %%
pinecone_index = pc.Index("quickstart")
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /indexes/quickstart
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /indexes/quickstart
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"name":"quickstart","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'
# response body: b'{"name":"quickstart","metric":"euclidean","dimension":1536,"status":{"ready":true,"state":"Ready"},"host":"quickstart-sohrk74.svc.aped-4627-b74a.pinecone.io","spec":{"serverless":{"region":"us-east-1","cloud":"aws"}},"deletion_protection":"disabled"}'

# %%
from llama_index.core import Settings
from llama_index.core import StorageContext
from llama_index.vector_stores.pinecone import PineconeVectorStore
from llama_index.core.node_parser import TokenTextSplitter
from llama_index.llms.openai import OpenAI

# define node parser and LLM
Settings.llm = OpenAI(temperature=0, model="gpt-4o-mini")
Settings.node_parser = TokenTextSplitter(chunk_size=1024)

# define pinecone vector index
vector_store = PineconeVectorStore(
    pinecone_index=pinecone_index, namespace="wiki_cities"
)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
vector_index = VectorStoreIndex([], storage_context=storage_context)
# Out:
# **********
# Trace: index_construction
# **********

# %%
# Insert documents into vector index
# Each document has metadata of the city attached
for city, wiki_doc in zip(cities, wiki_docs):
    nodes = Settings.node_parser.get_nodes_from_documents([wiki_doc])
    # add metadata to each node
    for node in nodes:
        node.metadata = {"title": city}
    vector_index.insert_nodes(nodes)
# Out:
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Toronto is the most populous city in Canada and...
# > Adding chunk: Toronto is the most populous city in Canada and...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Hill) on the banks of the Rouge River and Teiai...
# > Adding chunk: Hill) on the banks of the Rouge River and Teiai...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: city was also the location of Government House,...
# > Adding chunk: city was also the location of Government House,...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: doubled to two million by 1971. Following the e...
# > Adding chunk: doubled to two million by 1971. Following the e...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: as one of 16 cities in North America (and one o...
# > Adding chunk: as one of 16 cities in North America (and one o...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The former mouth drained into a wetland; today,...
# > Adding chunk: The former mouth drained into a wetland; today,...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: the former boroughs were promoted to cities. Hi...
# > Adding chunk: the former boroughs were promoted to cities. Hi...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: and Will Alsop's distinctive OCAD University ex...
# > Adding chunk: and Will Alsop's distinctive OCAD University ex...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Smith Trail opened in 2011 and is Toronto's fir...
# > Adding chunk: Smith Trail opened in 2011 and is Toronto's fir...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: cities in the world. In 2010, it was estimated ...
# > Adding chunk: cities in the world. In 2010, it was estimated ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: steel, food, machinery, chemicals and paper. Th...
# > Adding chunk: steel, food, machinery, chemicals and paper. Th...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: and do not permit private motor vehicles beyond...
# > Adding chunk: and do not permit private motor vehicles beyond...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: University, a private university based in Bosto...
# > Adding chunk: University, a private university based in Bosto...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: with Vancouver. The Toronto International Film ...
# > Adding chunk: with Vancouver. The Toronto International Film ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: won five National Lacrosse League Cup titles in...
# > Adding chunk: won five National Lacrosse League Cup titles in...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: are about 40 subcommittees and advisory committ...
# > Adding chunk: are about 40 subcommittees and advisory committ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: city has many forms of transport, including hig...
# > Adding chunk: city has many forms of transport, including hig...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: of Eglinton Avenue. This arrangement is sometim...
# > Adding chunk: of Eglinton Avenue. This arrangement is sometim...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180
GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba85c7a98a550d-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:30:24 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '195', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '978900', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '1.266s', 'x-request-id': 'req_c28e23f10158060e3cc221baa2b67e69', 'cf-cache-status': 'DYNAMIC', 'set-cookie': '__cf_bm=xMSC7gNSKhyxYJ6RGnfQNWF9p6x6cDIAdYsoI.MWhH8-1730449824-1.0.1.1-bW_bKk7Qc04B9SZSLZ17aomOwFF8BISgvcAE7pu3k.mZ_6Oq2MYOCxN.7yI3iMrpJYqZPt_9pPHooZWHslxE3w; path=/; expires=Fri, 01-Nov-24 09:00:24 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba85c7a98a550d-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_c28e23f10158060e3cc221baa2b67e69
# request_id: req_c28e23f10158060e3cc221baa2b67e69
# Upserted vectors:   0%|          | 0/18 [00:00<?, ?it/s]
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"upsertedCount":18}'
# response body: b'{"upsertedCount":18}'
# Upserted vectors: 100%|██████████| 18/18 [00:03<00:00,  4.64it/s]
# **********
# Trace: insert_nodes
#     |_embedding -> 1.450323 seconds
# **********
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Berlin is the capital and largest city of Germa...
# > Adding chunk: Berlin is the capital and largest city of Germa...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: BC. A deer mask, dated to 9,000 BC, is attribut...
# > Adding chunk: BC. A deer mask, dated to 9,000 BC, is attribut...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: to 21st centuries ===
#
# In the early 20th centur...
# > Adding chunk: to 21st centuries ===
#
# In the early 20th centur...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: West Germany with a unique legal status, while ...
# > Adding chunk: West Germany with a unique legal status, while ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: voted in favor by a small margin, largely based...
# > Adding chunk: voted in favor by a small margin, largely based...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: structures have been reconstructed, including t...
# > Adding chunk: structures have been reconstructed, including t...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: left in ruins. Nearby on Tauentzienstraße is Ka...
# > Adding chunk: left in ruins. Nearby on Tauentzienstraße is Ka...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: and Friedrichshain-Kreuzberg. The number of Ara...
# > Adding chunk: and Friedrichshain-Kreuzberg. The number of Ara...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: congregations of the Church of Jesus Christ of ...
# > Adding chunk: congregations of the Church of Jesus Christ of ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Germany. Discussions about moving the remaining...
# > Adding chunk: Germany. Discussions about moving the remaining...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: CityCube Berlin or the Berlin Congress Center (...
# > Adding chunk: CityCube Berlin or the Berlin Congress Center (...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: has 710 bicycles per 1,000 residents. Around 50...
# > Adding chunk: has 710 bicycles per 1,000 residents. Around 50...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: electric energy is imported from nearby power p...
# > Adding chunk: electric energy is imported from nearby power p...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: students. The Berlin School of Economics and La...
# > Adding chunk: students. The Berlin School of Economics and La...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: has a large collection of historical technical ...
# > Adding chunk: has a large collection of historical technical ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The Deutsches Theater in Mitte was built in 184...
# > Adding chunk: The Deutsches Theater in Mitte was built in 184...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: older of two zoos in the city, was founded in 1...
# > Adding chunk: older of two zoos in the city, was founded in 1...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C4FECDC0>, 'json_data': {'input': ['title: Berlin  Berlin is the capital and largest city of Germany, both by area and by population. Its more than 3.85 million inhabitants make it the European Union\'s most populous city, as measured by population within city limits. The city is also one of the states of Germany, and is the third smallest state in the country in terms of area. Berlin is surrounded by the state of Brandenburg, and Brandenburg\'s capital Potsdam is nearby. The urban area of Berlin has a population of over 4.5 million and is therefore the most populous urban area in Germany. The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany\'s second-largest metropolitan region after the Rhine-Ruhr region, and the sixth-biggest metropolitan region by GDP in the European Union. Berlin was built along the banks of the Spree river, which flows into the Havel in the western borough of Spandau. The city incorporates lakes in the western and southeastern boroughs, the largest of which is Müggelsee. About one-third of the city\'s area is composed of forests, parks and gardens, rivers, canals, and lakes. First documented in the 13th century and at the crossing of two important historic trade routes, Berlin was designated the capital of the Margraviate of Brandenburg (1417–1701), Kingdom of Prussia (1701–1918), German Empire (1871–1918), Weimar Republic (1919–1933), and Nazi Germany (1933–1945). Berlin has served as a scientific, artistic, and philosophical hub during the Age of Enlightenment, Neoclassicism, and the German revolutions of 1848–1849. During the Gründerzeit, an industrialization-induced economic boom triggered a rapid population increase in Berlin. 1920s Berlin was the third-largest city in the world by population. After World War II and following Berlin\'s occupation, the city was split into West Berlin and East Berlin, divided by the Berlin Wall. East Berlin was declared the capital of East Germany, while Bonn became the West German capital. Following German reunification in 1990, Berlin once again became the capital of all of Germany. Due to its geographic location and history, Berlin has been called "the heart of Europe". The economy of Berlin is based on high tech and the service sector, encompassing a diverse range of creative industries, startup companies, research facilities, and media corporations. Berlin serves as a continental hub for air and rail traffic and has a complex public transportation network. Tourism in Berlin makes the city a popular global destination. Significant industries include information technology, the healthcare industry, biomedical engineering, biotechnology, the automotive industry, and electronics. Berlin is home to several universities such as the Humboldt University of Berlin, Technische Universität Berlin, the Berlin University of the Arts and the Free University of Berlin. The Berlin Zoological Garden is the most visited zoo in Europe. Babelsberg Studio is the world\'s first large-scale movie studio complex and the list of films set in Berlin is long. Berlin is also home to three World Heritage Sites: Museum Island, the Palaces and Parks of Potsdam and Berlin, and the Berlin Modernism Housing Estates. Other landmarks include the Brandenburg Gate, the Reichstag building, Potsdamer Platz, the Memorial to the Murdered Jews of Europe, and the Berlin Wall Memorial. Berlin has numerous museums, galleries, and libraries.   == History ==   === Etymology === Berlin lies in northeastern Germany. Most of the cities and villages in northeastern Germany bear Slavic languages-derived names. Typical Germanization for place name suffixes of Slavic origin are -ow, -itz, -vitz, -witz, -itzsch and -in, prefixes are Windisch and Wendisch. The name Berlin has its roots in the language of the West Sla ...
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C4FECDC0>, 'json_data': {'input': ['title: Berlin  Berlin is the capital and largest city of Germany, both by area and by population. Its more than 3.85 million inhabitants make it the European Union\'s most populous city, as measured by population within city limits. The city is also one of the states of Germany, and is the third smallest state in the country in terms of area. Berlin is surrounded by the state of Brandenburg, and Brandenburg\'s capital Potsdam is nearby. The urban area of Berlin has a population of over 4.5 million and is therefore the most populous urban area in Germany. The Berlin-Brandenburg capital region has around 6.2 million inhabitants and is Germany\'s second-largest metropolitan region after the Rhine-Ruhr region, and the sixth-biggest metropolitan region by GDP in the European Union. Berlin was built along the banks of the Spree river, which flows into the Havel in the western borough of Spandau. The city incorporates lakes in the western and southeastern boroughs, the largest of which is Müggelsee. About one-third of the city\'s area is composed of forests, parks and gardens, rivers, canals, and lakes. First documented in the 13th century and at the crossing of two important historic trade routes, Berlin was designated the capital of the Margraviate of Brandenburg (1417–1701), Kingdom of Prussia (1701–1918), German Empire (1871–1918), Weimar Republic (1919–1933), and Nazi Germany (1933–1945). Berlin has served as a scientific, artistic, and philosophical hub during the Age of Enlightenment, Neoclassicism, and the German revolutions of 1848–1849. During the Gründerzeit, an industrialization-induced economic boom triggered a rapid population increase in Berlin. 1920s Berlin was the third-largest city in the world by population. After World War II and following Berlin\'s occupation, the city was split into West Berlin and East Berlin, divided by the Berlin Wall. East Berlin was declared the capital of East Germany, while Bonn became the West German capital. Following German reunification in 1990, Berlin once again became the capital of all of Germany. Due to its geographic location and history, Berlin has been called "the heart of Europe". The economy of Berlin is based on high tech and the service sector, encompassing a diverse range of creative industries, startup companies, research facilities, and media corporations. Berlin serves as a continental hub for air and rail traffic and has a complex public transportation network. Tourism in Berlin makes the city a popular global destination. Significant industries include information technology, the healthcare industry, biomedical engineering, biotechnology, the automotive industry, and electronics. Berlin is home to several universities such as the Humboldt University of Berlin, Technische Universität Berlin, the Berlin University of the Arts and the Free University of Berlin. The Berlin Zoological Garden is the most visited zoo in Europe. Babelsberg Studio is the world\'s first large-scale movie studio complex and the list of films set in Berlin is long. Berlin is also home to three World Heritage Sites: Museum Island, the Palaces and Parks of Potsdam and Berlin, and the Berlin Modernism Housing Estates. Other landmarks include the Brandenburg Gate, the Reichstag building, Potsdamer Platz, the Memorial to the Murdered Jews of Europe, and the Berlin Wall Memorial. Berlin has numerous museums, galleries, and libraries.   == History ==   === Etymology === Berlin lies in northeastern Germany. Most of the cities and villages in northeastern Germany bear Slavic languages-derived names. Typical Germanization for place name suffixes of Slavic origin are -ow, -itz, -vitz, -witz, -itzsch and -in, prefixes are Windisch and Wendisch. The name Berlin has its roots in the language of the West Slavs, and may be related to  ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:30:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'485'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'980185'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'1.188s'), (b'x-request-id', b'req_392fbc06c5e37cc661646400ee789c3d'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba85eddf29550d-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:30:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'485'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'980185'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'1.188s'), (b'x-request-id', b'req_392fbc06c5e37cc661646400ee789c3d'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba85eddf29550d-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:30:31 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '485', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '980185', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '1.188s', 'x-request-id': 'req_392fbc06c5e37cc661646400ee789c3d', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba85eddf29550d-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:30:31 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '485', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '980185', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '1.188s', 'x-request-id': 'req_392fbc06c5e37cc661646400ee789c3d', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba85eddf29550d-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_392fbc06c5e37cc661646400ee789c3d
# request_id: req_392fbc06c5e37cc661646400ee789c3d
# Upserted vectors:   0%|          | 0/17 [00:00<?, ?it/s]
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"upsertedCount":17}'
# response body: b'{"upsertedCount":17}'
# Upserted vectors: 100%|██████████| 17/17 [00:00<00:00, 19.71it/s]
# **********
# Trace: insert_nodes
#     |_embedding -> 2.133641 seconds
# **********
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Tokyo, officially the Tokyo Metropolis, is the ...
# > Adding chunk: Tokyo, officially the Tokyo Metropolis, is the ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: the city was changed to Tokyo (東京, from 東 tō "e...
# > Adding chunk: the city was changed to Tokyo (東京, from 東 tō "e...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: which is now part of the Tokaido line. The 1870...
# > Adding chunk: which is now part of the Tokaido line. The 1870...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: the war, Tokyo became the base from which the A...
# > Adding chunk: the war, Tokyo became the base from which the A...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: July 23 to August 8, 2021, as a result of the C...
# > Adding chunk: July 23 to August 8, 2021, as a result of the C...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: area.
# Tokyo has numerous outlying islands, whic...
# > Adding chunk: area.
# Tokyo has numerous outlying islands, whic...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: west, Kanagawa to the south, and Saitama to the...
# > Adding chunk: west, Kanagawa to the south, and Saitama to the...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 1782, 1812, 1855, 1923, and much more indirectl...
# > Adding chunk: 1782, 1812, 1855, 1923, and much more indirectl...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: at one point, these houses amounted to half the...
# > Adding chunk: at one point, these houses amounted to half the...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: but 2.4 million during the day.
# According to Ap...
# > Adding chunk: but 2.4 million during the day.
# According to Ap...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Chiyoda (Marunouchi, Otemachi, Kasumigaseki), C...
# > Adding chunk: Chiyoda (Marunouchi, Otemachi, Kasumigaseki), C...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 2022 government survey, the most visited areas ...
# > Adding chunk: 2022 government survey, the most visited areas ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: different entities operate Tokyo's underground ...
# > Adding chunk: different entities operate Tokyo's underground ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Kisen, which serves islands such as Izu Ōshima,...
# > Adding chunk: Kisen, which serves islands such as Izu Ōshima,...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Museum in Aoyama has a collection of pre-modern...
# > Adding chunk: Museum in Aoyama has a collection of pre-modern...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gyoen National Garden, Koishikawa Korakuen Gard...
# > Adding chunk: Gyoen National Garden, Koishikawa Korakuen Gard...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Sister cities and states ===
#
# As of 2022, Tokyo...
# > Adding chunk: Sister cities and states ===
#
# As of 2022, Tokyo...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C4FEDBD0>, 'json_data': {'input': ['title: Tokyo  Tokyo, officially the Tokyo Metropolis, is the capital of Japan and one of the most populous cities in the world, with a population of over 14 million residents within the city proper as of 2023. The Greater Tokyo Area, which includes Tokyo and parts of six neighboring prefectures, is the most-populous metropolitan area in the world, with 41 million residents as of 2024. Located at the head of Tokyo Bay, Tokyo is part of the Kantō region on the central coast of Honshu, Japan\'s largest island. Tokyo serves as Japan\'s economic center and the seat of both the Japanese government and the Emperor of Japan. The Tokyo Metropolitan Government administers Tokyo\'s central 23 special wards (which formerly made up Tokyo City), various commuter towns and suburbs in its western area, and two outlying island chains known as the Tokyo Islands. Despite most of the world recognizing Tokyo as a city, since 1943 its governing structure has been more akin to a prefecture, with an accompanying Governor and Assembly taking precedence over the smaller municipal governments which make up the metropolis. Notable special wards in Tokyo include Chiyoda, the site of the National Diet Building and the Tokyo Imperial Palace; Shinjuku, the city\'s administrative center; and Shibuya, a commercial, cultural, and business hub in the city. Before the 17th century, Tokyo, then known as Edo, was mainly a fishing village. It gained political prominence in 1603 when it became the seat of the Tokugawa shogunate. By the mid-18th century, Edo was among the world\'s largest cities, with over a million residents. Following the Meiji Restoration in 1868, the imperial capital in Kyoto was moved to Edo, and the city was renamed Tokyo (lit.\u2009\'Eastern Capital\'). In 1923, Tokyo was damaged substantially by the Great Kantō earthquake, and the city was later badly damaged by allied bombing raids during World War II. Beginning in the late 1940s, Tokyo underwent rapid reconstruction and expansion that contributed to the era\'s so-called Japanese economic miracle in which Japan\'s economy propelled to the second-largest in the world at the time behind that of the United States. As of 2023, the city is home to 29 of the world\'s 500 largest companies, as listed in the annual Fortune Global 500; the second-highest number of any city. In the 20th and 21st centuries, Tokyo became the first city in Asia to host the Summer Olympics and Paralympics in 1964, and again in 2021, and it also hosted three G7 summits in 1979, 1986, and 1993. Tokyo is an international research and development hub and an academic center with several major universities, including the University of Tokyo, the top-ranking university in the country. Tokyo Station is the central hub for the Shinkansen, Japan\'s high-speed railway network, and Shinjuku Station in Tokyo is the world\'s busiest train station. The city is home to the world\'s tallest tower, Tokyo Skytree. The Tokyo Metro Ginza Line, which opened in 1927, is the oldest underground metro line in Asia–Pacific. Tokyo\'s nominal gross domestic output was 113.7 trillion yen or US$1.04 trillion in FY2021 and accounted for 20.7% of the country\'s total economic output, which converts to 8.07 million yen or US$73,820 per capita. Including the Greater Tokyo Area, Tokyo is the second-largest metropolitan economy in the world after New York, with a 2022 gross metropolitan product estimated at US$2.08 trillion. Although Tokyo\'s status as a leading global financial hub has diminished with the Lost Decades since the 1990s—when the Tokyo Stock Exchange was the world\'s largest, with a market capitalization about 1.5 times that of the NYSE—the city is still a large financial hub, and the TSE remains among the world\'s top five major stock exchan ...
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C4FEDBD0>, 'json_data': {'input': ['title: Tokyo  Tokyo, officially the Tokyo Metropolis, is the capital of Japan and one of the most populous cities in the world, with a population of over 14 million residents within the city proper as of 2023. The Greater Tokyo Area, which includes Tokyo and parts of six neighboring prefectures, is the most-populous metropolitan area in the world, with 41 million residents as of 2024. Located at the head of Tokyo Bay, Tokyo is part of the Kantō region on the central coast of Honshu, Japan\'s largest island. Tokyo serves as Japan\'s economic center and the seat of both the Japanese government and the Emperor of Japan. The Tokyo Metropolitan Government administers Tokyo\'s central 23 special wards (which formerly made up Tokyo City), various commuter towns and suburbs in its western area, and two outlying island chains known as the Tokyo Islands. Despite most of the world recognizing Tokyo as a city, since 1943 its governing structure has been more akin to a prefecture, with an accompanying Governor and Assembly taking precedence over the smaller municipal governments which make up the metropolis. Notable special wards in Tokyo include Chiyoda, the site of the National Diet Building and the Tokyo Imperial Palace; Shinjuku, the city\'s administrative center; and Shibuya, a commercial, cultural, and business hub in the city. Before the 17th century, Tokyo, then known as Edo, was mainly a fishing village. It gained political prominence in 1603 when it became the seat of the Tokugawa shogunate. By the mid-18th century, Edo was among the world\'s largest cities, with over a million residents. Following the Meiji Restoration in 1868, the imperial capital in Kyoto was moved to Edo, and the city was renamed Tokyo (lit.\u2009\'Eastern Capital\'). In 1923, Tokyo was damaged substantially by the Great Kantō earthquake, and the city was later badly damaged by allied bombing raids during World War II. Beginning in the late 1940s, Tokyo underwent rapid reconstruction and expansion that contributed to the era\'s so-called Japanese economic miracle in which Japan\'s economy propelled to the second-largest in the world at the time behind that of the United States. As of 2023, the city is home to 29 of the world\'s 500 largest companies, as listed in the annual Fortune Global 500; the second-highest number of any city. In the 20th and 21st centuries, Tokyo became the first city in Asia to host the Summer Olympics and Paralympics in 1964, and again in 2021, and it also hosted three G7 summits in 1979, 1986, and 1993. Tokyo is an international research and development hub and an academic center with several major universities, including the University of Tokyo, the top-ranking university in the country. Tokyo Station is the central hub for the Shinkansen, Japan\'s high-speed railway network, and Shinjuku Station in Tokyo is the world\'s busiest train station. The city is home to the world\'s tallest tower, Tokyo Skytree. The Tokyo Metro Ginza Line, which opened in 1927, is the oldest underground metro line in Asia–Pacific. Tokyo\'s nominal gross domestic output was 113.7 trillion yen or US$1.04 trillion in FY2021 and accounted for 20.7% of the country\'s total economic output, which converts to 8.07 million yen or US$73,820 per capita. Including the Greater Tokyo Area, Tokyo is the second-largest metropolitan economy in the world after New York, with a 2022 gross metropolitan product estimated at US$2.08 trillion. Although Tokyo\'s status as a leading global financial hub has diminished with the Lost Decades since the 1990s—when the Tokyo Stock Exchange was the world\'s largest, with a market capitalization about 1.5 times that of the NYSE—the city is still a large financial hub, and the TSE remains among the world\'s top five major stock exchanges. Tokyo is categorized  ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:30:34 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'220'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'981514'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'1.109s'), (b'x-request-id', b'req_5c9997c9f2cbe1bc06fbd6e592462569'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba86055b9a550d-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:30:34 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'220'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'981514'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'1.109s'), (b'x-request-id', b'req_5c9997c9f2cbe1bc06fbd6e592462569'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba86055b9a550d-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:30:34 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '220', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '981514', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '1.109s', 'x-request-id': 'req_5c9997c9f2cbe1bc06fbd6e592462569', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba86055b9a550d-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:30:34 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '220', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '981514', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '1.109s', 'x-request-id': 'req_5c9997c9f2cbe1bc06fbd6e592462569', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba86055b9a550d-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_5c9997c9f2cbe1bc06fbd6e592462569
# request_id: req_5c9997c9f2cbe1bc06fbd6e592462569
# Upserted vectors:   0%|          | 0/17 [00:00<?, ?it/s]
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"upsertedCount":17}'
# response body: b'{"upsertedCount":17}'
# Upserted vectors: 100%|██████████| 17/17 [00:00<00:00, 19.59it/s]
# **********
# Trace: insert_nodes
#     |_embedding -> 1.755061 seconds
# **********

# %%
from llama_index.core.retrievers import VectorIndexAutoRetriever
from llama_index.core.vector_stores import MetadataInfo, VectorStoreInfo
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.tools import QueryEngineTool


vector_store_info = VectorStoreInfo(
    content_info="articles about different cities",
    metadata_info=[
        MetadataInfo(
            name="title", type="str", description="The name of the city"
        ),
    ],
)
vector_auto_retriever = VectorIndexAutoRetriever(
    vector_index, vector_store_info=vector_store_info
)

retriever_query_engine = RetrieverQueryEngine.from_args(
    vector_auto_retriever,
)

# %%
sql_tool = QueryEngineTool.from_defaults(
    query_engine=query_engine,
    name="sql_tool",
    description=(
        "Useful for translating a natural language query into a SQL query over"
        " a table containing: city_stats, containing the population/country of"
        " each city"
    ),
)
vector_tool = QueryEngineTool.from_defaults(
    query_engine=retriever_query_engine,
    name="vector_tool",
    description=(
        f"Useful for answering semantic questions about different cities"
    ),
)

# %% [markdown]
# # Initialize Agent

# %%
from llama_index.agent.openai import OpenAIAgent
from llama_index.llms.openai import OpenAI

agent = OpenAIAgent.from_tools(
    [sql_tool, vector_tool],
    llm=OpenAI(temperature=0, model="gpt-4o-mini"),
    verbose=True,
)

# %%
# NOTE: gpt-3.5 gives the wrong answer, but gpt-4 is able to reason over both loops
response = agent.chat(
    "Tell me about the arts and culture of the city with the highest"
    " population"
)
print(str(response))
# Out:
# Added user message to memory: Tell me about the arts and culture of the city with the highest population
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'vector_tool', 'description': 'Useful for answering semantic questions about different cities', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}]}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'vector_tool', 'description': 'Useful for answering semantic questions about different cities', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}]}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E59AB0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E59AB0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E59A80>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E59A80>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:28 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'459'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'199963'), (b'x-ratelimit-reset-requests', b'8.64s'), (b'x-ratelimit-reset-tokens', b'10ms'), (b'x-request-id', b'req_57b53f5676fcf425206fee7676a122ac'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=UcJRmcdO27Xj4Y17Ztxhu1HPqIWjoJFwmAYSWh40rBY-1730449888-1.0.1.1-UFaUVtjPThV8J2yhpnSjBMGVRMWmnuvEA6MwqaUVr1.0hQMO11950_giTj_9wIqLW2BFdsRLI3f5NxEMVkmFkw; path=/; expires=Fri, 01-Nov-24 09:01:28 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=QJtxOPtt25Jq9diMSGig97J6C6pDY.kKwj9alzB6yh4-1730449888141-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8753eec3918b-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:28 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'459'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'199963'), (b'x-ratelimit-reset-requests', b'8.64s'), (b'x-ratelimit-reset-tokens', b'10ms'), (b'x-request-id', b'req_57b53f5676fcf425206fee7676a122ac'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=UcJRmcdO27Xj4Y17Ztxhu1HPqIWjoJFwmAYSWh40rBY-1730449888-1.0.1.1-UFaUVtjPThV8J2yhpnSjBMGVRMWmnuvEA6MwqaUVr1.0hQMO11950_giTj_9wIqLW2BFdsRLI3f5NxEMVkmFkw; path=/; expires=Fri, 01-Nov-24 09:01:28 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=QJtxOPtt25Jq9diMSGig97J6C6pDY.kKwj9alzB6yh4-1730449888141-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8753eec3918b-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Fri, 01 Nov 2024 08:31:28 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-f8xnqrzkrmt0qbpgbtsecvpc'), ('openai-processing-ms', '459'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '10000'), ('x-ratelimit-limit-tokens', '200000'), ('x-ratelimit-remaining-requests', '9999'), ('x-ratelimit-remaining-tokens', '199963'), ('x-ratelimit-reset-requests', '8.64s'), ('x-ratelimit-reset-tokens', '10ms'), ('x-request-id', 'req_57b53f5676fcf425206fee7676a122ac'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=UcJRmcdO27Xj4Y17Ztxhu1HPqIWjoJFwmAYSWh40rBY-1730449888-1.0.1.1-UFaUVtjPThV8J2yhpnSjBMGVRMWmnuvEA6MwqaUVr1.0hQMO11950_giTj_9wIqLW2BFdsRLI3f5NxEMVkmFkw; path=/; expires=Fri, 01-Nov-24 09:01:28 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=QJtxOPtt25Jq9diMSGig97J6C6pDY.kKwj9alzB6yh4-1730449888141-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '8dba8753eec3918b-DEL'), ('content-encoding', 'gzip'), ('alt-svc', 'h3=":443"; ma=86400')])
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Fri, 01 Nov 2024 08:31:28 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-f8xnqrzkrmt0qbpgbtsecvpc'), ('openai-processing-ms', '459'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '10000'), ('x-ratelimit-limit-tokens', '200000'), ('x-ratelimit-remaining-requests', '9999'), ('x-ratelimit-remaining-tokens', '199963'), ('x-ratelimit-reset-requests', '8.64s'), ('x-ratelimit-reset-tokens', '10ms'), ('x-request-id', 'req_57b53f5676fcf425206fee7676a122ac'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=UcJRmcdO27Xj4Y17Ztxhu1HPqIWjoJFwmAYSWh40rBY-1730449888-1.0.1.1-UFaUVtjPThV8J2yhpnSjBMGVRMWmnuvEA6MwqaUVr1.0hQMO11950_giTj_9wIqLW2BFdsRLI3f5NxEMVkmFkw; path=/; expires=Fri, 01-Nov-24 09:01:28 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=QJtxOPtt25Jq9diMSGig97J6C6pDY.kKwj9alzB6yh4-1730449888141-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '8dba8753eec3918b-DEL'), ('content-encoding', 'gzip'), ('alt-svc', 'h3=":443"; ma=86400')])
# DEBUG:openai._base_client:request_id: req_57b53f5676fcf425206fee7676a122ac
# request_id: req_57b53f5676fcf425206fee7676a122ac
# === Calling Function ===
# Calling function: sql_tool with args: {"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}
# INFO:llama_index.core.indices.struct_store.sql_retriever:> Table desc str: Table 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .
# > Table desc str: Table 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, first create a syntactically correct sqlite query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return the most interesting examples in the database.\n\nNever query for all the columns from a specific table, only ask for a few relevant columns given the question.\n\nPay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Pay attention to which column is in which table. Also, qualify column names with the table name when needed. You are required to use the following format, each taking one line:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use tables listed below.\nTable 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .\n\nQuestion: SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;\nSQLQuery: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, first create a syntactically correct sqlite query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return the most interesting examples in the database.\n\nNever query for all the columns from a specific table, only ask for a few relevant columns given the question.\n\nPay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Pay attention to which column is in which table. Also, qualify column names with the table name when needed. You are required to use the following format, each taking one line:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use tables listed below.\nTable 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .\n\nQuestion: SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;\nSQLQuery: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5ACB0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5ACB0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5AB90>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5AB90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:29 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1078'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'199727'), (b'x-ratelimit-reset-requests', b'16.38s'), (b'x-ratelimit-reset-tokens', b'81ms'), (b'x-request-id', b'req_930bf0bbc31f95a3ea05e0201b7f3a8d'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=ejVeGefveC5JpcsvnPzrndiw_CpAFXCTHSVsBee1jbk-1730449889-1.0.1.1-nrSv4rcB41Ir1BOJT5R4KksUcChjTv9Wg8sWX4ub.BmYtANL.Zc8Q1ZDUg_V2KAe4GCjtIQDCp_qPAGpM_LXAg; path=/; expires=Fri, 01-Nov-24 09:01:29 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba87598cdf5506-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:29 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'1078'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'199727'), (b'x-ratelimit-reset-requests', b'16.38s'), (b'x-ratelimit-reset-tokens', b'81ms'), (b'x-request-id', b'req_930bf0bbc31f95a3ea05e0201b7f3a8d'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=ejVeGefveC5JpcsvnPzrndiw_CpAFXCTHSVsBee1jbk-1730449889-1.0.1.1-nrSv4rcB41Ir1BOJT5R4KksUcChjTv9Wg8sWX4ub.BmYtANL.Zc8Q1ZDUg_V2KAe4GCjtIQDCp_qPAGpM_LXAg; path=/; expires=Fri, 01-Nov-24 09:01:29 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba87598cdf5506-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:29 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1078', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9998', 'x-ratelimit-remaining-tokens': '199727', 'x-ratelimit-reset-requests': '16.38s', 'x-ratelimit-reset-tokens': '81ms', 'x-request-id': 'req_930bf0bbc31f95a3ea05e0201b7f3a8d', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'set-cookie': '__cf_bm=ejVeGefveC5JpcsvnPzrndiw_CpAFXCTHSVsBee1jbk-1730449889-1.0.1.1-nrSv4rcB41Ir1BOJT5R4KksUcChjTv9Wg8sWX4ub.BmYtANL.Zc8Q1ZDUg_V2KAe4GCjtIQDCp_qPAGpM_LXAg; path=/; expires=Fri, 01-Nov-24 09:01:29 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba87598cdf5506-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:29 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '1078', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9998', 'x-ratelimit-remaining-tokens': '199727', 'x-ratelimit-reset-requests': '16.38s', 'x-ratelimit-reset-tokens': '81ms', 'x-request-id': 'req_930bf0bbc31f95a3ea05e0201b7f3a8d', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'set-cookie': '__cf_bm=ejVeGefveC5JpcsvnPzrndiw_CpAFXCTHSVsBee1jbk-1730449889-1.0.1.1-nrSv4rcB41Ir1BOJT5R4KksUcChjTv9Wg8sWX4ub.BmYtANL.Zc8Q1ZDUg_V2KAe4GCjtIQDCp_qPAGpM_LXAg; path=/; expires=Fri, 01-Nov-24 09:01:29 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba87598cdf5506-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_930bf0bbc31f95a3ea05e0201b7f3a8d
# request_id: req_930bf0bbc31f95a3ea05e0201b7f3a8d
# DEBUG:llama_index.core.indices.struct_store.sql_retriever:> Predicted SQL query: SELECT city_name, population FROM city_stats ORDER BY population DESC LIMIT 1;
# > Predicted SQL query: SELECT city_name, population FROM city_stats ORDER BY population DESC LIMIT 1;
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, synthesize a response from the query results.\nQuery: SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;\nSQL: SELECT city_name, population FROM city_stats ORDER BY population DESC LIMIT 1;\nSQL Response: [('Tokyo', 13960000)]\nResponse: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, synthesize a response from the query results.\nQuery: SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;\nSQL: SELECT city_name, population FROM city_stats ORDER BY population DESC LIMIT 1;\nSQL Response: [('Tokyo', 13960000)]\nResponse: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:30 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'479'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9997'), (b'x-ratelimit-remaining-tokens', b'199911'), (b'x-ratelimit-reset-requests', b'23.555s'), (b'x-ratelimit-reset-tokens', b'26ms'), (b'x-request-id', b'req_1d628e443b24a9f03ff3bea226f1da34'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8762ba235506-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:30 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'479'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9997'), (b'x-ratelimit-remaining-tokens', b'199911'), (b'x-ratelimit-reset-requests', b'23.555s'), (b'x-ratelimit-reset-tokens', b'26ms'), (b'x-request-id', b'req_1d628e443b24a9f03ff3bea226f1da34'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8762ba235506-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:30 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '479', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9997', 'x-ratelimit-remaining-tokens': '199911', 'x-ratelimit-reset-requests': '23.555s', 'x-ratelimit-reset-tokens': '26ms', 'x-request-id': 'req_1d628e443b24a9f03ff3bea226f1da34', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8762ba235506-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:30 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '479', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9997', 'x-ratelimit-remaining-tokens': '199911', 'x-ratelimit-reset-requests': '23.555s', 'x-ratelimit-reset-tokens': '26ms', 'x-request-id': 'req_1d628e443b24a9f03ff3bea226f1da34', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8762ba235506-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_1d628e443b24a9f03ff3bea226f1da34
# request_id: req_1d628e443b24a9f03ff3bea226f1da34
# Got output: The city with the highest population is Tokyo, which has a population of 13,960,000.
# ========================
#
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'vector_tool', 'description': 'Useful for answering semantic questions about different cities', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}]}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'vector_tool', 'description': 'Useful for answering semantic questions about different cities', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}]}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'437'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9996'), (b'x-ratelimit-remaining-tokens', b'199941'), (b'x-ratelimit-reset-requests', b'31.295s'), (b'x-ratelimit-reset-tokens', b'17ms'), (b'x-request-id', b'req_c99a5779942e44f61b71765a47f5afb2'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8768499b918b-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'437'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9996'), (b'x-ratelimit-remaining-tokens', b'199941'), (b'x-ratelimit-reset-requests', b'31.295s'), (b'x-ratelimit-reset-tokens', b'17ms'), (b'x-request-id', b'req_c99a5779942e44f61b71765a47f5afb2'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8768499b918b-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:31 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '437', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9996', 'x-ratelimit-remaining-tokens': '199941', 'x-ratelimit-reset-requests': '31.295s', 'x-ratelimit-reset-tokens': '17ms', 'x-request-id': 'req_c99a5779942e44f61b71765a47f5afb2', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8768499b918b-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:31 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '437', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9996', 'x-ratelimit-remaining-tokens': '199941', 'x-ratelimit-reset-requests': '31.295s', 'x-ratelimit-reset-tokens': '17ms', 'x-request-id': 'req_c99a5779942e44f61b71765a47f5afb2', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8768499b918b-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_c99a5779942e44f61b71765a47f5afb2
# request_id: req_c99a5779942e44f61b71765a47f5afb2
# === Calling Function ===
# Calling function: vector_tool with args: {"input":"arts and culture of Tokyo"}
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Code\\Github\\LlamaIndex\\venv\\Library\\ssl\\cacert.pem'
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Your goal is to structure the user\'s query to match the request schema provided below.\n\n<< Structured Request Schema >>\nWhen responding use a markdown code snippet with a JSON object formatted in the following schema:\n\n{\'$defs\': {\'FilterOperator\': {\'description\': \'Vector store filter operator.\', \'enum\': [\'==\', \'>\', \'<\', \'!=\', \'>=\', \'<=\', \'in\', \'nin\', \'any\', \'all\', \'text_match\', \'contains\', \'is_empty\'], \'title\': \'FilterOperator\', \'type\': \'string\'}, \'MetadataFilter\': {\'description\': \'Comprehensive metadata filter for vector stores to support more operators.\\n\\nValue uses Strict* types, as int, float and str are compatible types and were all\\nconverted to string before.\\n\\nSee: https://docs.pydantic.dev/latest/usage/types/#strict-types\', \'properties\': {\'key\': {\'title\': \'Key\', \'type\': \'string\'}, \'value\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'number\'}, {\'type\': \'string\'}, {\'items\': {\'type\': \'string\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'number\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'integer\'}, \'type\': \'array\'}, {\'type\': \'null\'}], \'title\': \'Value\'}, \'operator\': {\'$ref\': \'#/$defs/FilterOperator\', \'default\': \'==\'}}, \'required\': [\'key\', \'value\'], \'title\': \'MetadataFilter\', \'type\': \'object\'}}, \'description\': \'Schema for a structured request for vector store\\n(i.e. to be converted to a VectorStoreQuery).\\n\\nCurrently only used by VectorIndexAutoRetriever.\', \'properties\': {\'query\': {\'title\': \'Query\', \'type\': \'string\'}, \'filters\': {\'items\': {\'$ref\': \'#/$defs/MetadataFilter\'}, \'title\': \'Filters\', \'type\': \'array\'}, \'top_k\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'null\'}], \'default\': None, \'title\': \'Top K\'}}, \'required\': [\'query\', \'filters\'], \'title\': \'VectorStoreQuerySpec\', \'type\': \'object\'}\n\nThe query string should contain only text that is expected to match the contents of documents. Any conditions in the filter should not be mentioned in the query as well.\n\nMake sure that filters only refer to attributes that exist in the data source.\nMake sure that filters take into account the descriptions of attributes.\nMake sure that filters are only used as needed. If there are no filters that should be applied return [] for the filter value.\nIf the user\'s query explicitly mentions number of documents to retrieve, set top_k to that number, otherwise do not set top_k.\n\n<< Example 1. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "artist",\n            "type": "str",\n            "description": "Name of the song artist"\n        }},\n        {{\n            "name": "genre",\n            "type": "str",\n            "description": "The song genre, one of \\"pop\\", \\"rock\\" or \\"rap\\""\n        }}\n    ],\n    "content_info": "Lyrics of a song"\n}}\n```\n\nUser Query:\nWhat are songs by Taylor Swift or Katy Perry in the dance pop genre\n\nStructured Request:\n```json\n{{"query":"teenager love","filters":[{{"key":"artist","value":"Taylor Swift","operator":"=="}},{{"key":"artist","value":"Katy Perry","operator":"=="}},{{"key":"genre","value":"pop","operator":"=="}}],"top_k":null}}\n\n\n<< Example 2. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "author",\n            "type": "str",\n            "description": "Author name"\n        }},\n        {{\n            "name": "book_title",\n            "type": "str",\n            "description": "Book title"\n        }},\n        {{\n            "name": "year",\n            "type": "int",\n            "description": "Year Published"\n        }},\n        {{\n            "name": "pages",\n            "type": "int",\n            "description": ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Your goal is to structure the user\'s query to match the request schema provided below.\n\n<< Structured Request Schema >>\nWhen responding use a markdown code snippet with a JSON object formatted in the following schema:\n\n{\'$defs\': {\'FilterOperator\': {\'description\': \'Vector store filter operator.\', \'enum\': [\'==\', \'>\', \'<\', \'!=\', \'>=\', \'<=\', \'in\', \'nin\', \'any\', \'all\', \'text_match\', \'contains\', \'is_empty\'], \'title\': \'FilterOperator\', \'type\': \'string\'}, \'MetadataFilter\': {\'description\': \'Comprehensive metadata filter for vector stores to support more operators.\\n\\nValue uses Strict* types, as int, float and str are compatible types and were all\\nconverted to string before.\\n\\nSee: https://docs.pydantic.dev/latest/usage/types/#strict-types\', \'properties\': {\'key\': {\'title\': \'Key\', \'type\': \'string\'}, \'value\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'number\'}, {\'type\': \'string\'}, {\'items\': {\'type\': \'string\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'number\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'integer\'}, \'type\': \'array\'}, {\'type\': \'null\'}], \'title\': \'Value\'}, \'operator\': {\'$ref\': \'#/$defs/FilterOperator\', \'default\': \'==\'}}, \'required\': [\'key\', \'value\'], \'title\': \'MetadataFilter\', \'type\': \'object\'}}, \'description\': \'Schema for a structured request for vector store\\n(i.e. to be converted to a VectorStoreQuery).\\n\\nCurrently only used by VectorIndexAutoRetriever.\', \'properties\': {\'query\': {\'title\': \'Query\', \'type\': \'string\'}, \'filters\': {\'items\': {\'$ref\': \'#/$defs/MetadataFilter\'}, \'title\': \'Filters\', \'type\': \'array\'}, \'top_k\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'null\'}], \'default\': None, \'title\': \'Top K\'}}, \'required\': [\'query\', \'filters\'], \'title\': \'VectorStoreQuerySpec\', \'type\': \'object\'}\n\nThe query string should contain only text that is expected to match the contents of documents. Any conditions in the filter should not be mentioned in the query as well.\n\nMake sure that filters only refer to attributes that exist in the data source.\nMake sure that filters take into account the descriptions of attributes.\nMake sure that filters are only used as needed. If there are no filters that should be applied return [] for the filter value.\nIf the user\'s query explicitly mentions number of documents to retrieve, set top_k to that number, otherwise do not set top_k.\n\n<< Example 1. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "artist",\n            "type": "str",\n            "description": "Name of the song artist"\n        }},\n        {{\n            "name": "genre",\n            "type": "str",\n            "description": "The song genre, one of \\"pop\\", \\"rock\\" or \\"rap\\""\n        }}\n    ],\n    "content_info": "Lyrics of a song"\n}}\n```\n\nUser Query:\nWhat are songs by Taylor Swift or Katy Perry in the dance pop genre\n\nStructured Request:\n```json\n{{"query":"teenager love","filters":[{{"key":"artist","value":"Taylor Swift","operator":"=="}},{{"key":"artist","value":"Katy Perry","operator":"=="}},{{"key":"genre","value":"pop","operator":"=="}}],"top_k":null}}\n\n\n<< Example 2. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "author",\n            "type": "str",\n            "description": "Author name"\n        }},\n        {{\n            "name": "book_title",\n            "type": "str",\n            "description": "Book title"\n        }},\n        {{\n            "name": "year",\n            "type": "int",\n            "description": "Year Published"\n        }},\n        {{\n            "name": "pages",\n            "type": "int",\n            "description": "Number of pages"\n       ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7DD80>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7DD80>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C9E498C0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C9E498C0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7DC30>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7DC30>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:33 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'971'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9995'), (b'x-ratelimit-remaining-tokens', b'198870'), (b'x-ratelimit-reset-requests', b'38.633s'), (b'x-ratelimit-reset-tokens', b'339ms'), (b'x-request-id', b'req_b3a644be60540ec61991721a19101816'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=Oz0__Fs7RajtNh57icCEXrAk80VQQUOLgdqP8eaa6gk-1730449893-1.0.1.1-fSQIklNberUgy_vzL9oL7GDkS_Eou8lqv528RgU2KbRQZ7JNJL77K5he2c7fwqNShB1hMnrDQ.4ob_KXHnMv2A; path=/; expires=Fri, 01-Nov-24 09:01:33 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=ge.Gdya2Makho4Wr0zOWqg3A8YEwegKmAEfW1eU5OYQ-1730449893215-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba87707c4e9192-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# ...
# DEBUG:openai._base_client:request_id: req_3446127ac26fa7dde489f60975f78193
# request_id: req_3446127ac26fa7dde489f60975f78193
# Got output: Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.
#
# Art galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.
#
# Tokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.
#
# Overall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.
# ========================
#
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'vector_tool', 'description': 'Useful for answering semantic questions about different cities', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}]}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'vector_tool', 'description': 'Useful for answering semantic questions about different cities', 'parameters': {'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'type': 'object'}}}]}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C85BDDE0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C85BDDE0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5A290>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5A290>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:44 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'5749'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9994'), (b'x-ratelimit-remaining-tokens', b'199636'), (b'x-ratelimit-reset-requests', b'49.169s'), (b'x-ratelimit-reset-tokens', b'109ms'), (b'x-request-id', b'req_63b7a2b5a962ad9b5d5cf91db126d21b'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba879aadd25994-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:31:44 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'5749'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9994'), (b'x-ratelimit-remaining-tokens', b'199636'), (b'x-ratelimit-reset-requests', b'49.169s'), (b'x-ratelimit-reset-tokens', b'109ms'), (b'x-request-id', b'req_63b7a2b5a962ad9b5d5cf91db126d21b'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba879aadd25994-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:44 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '5749', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9994', 'x-ratelimit-remaining-tokens': '199636', 'x-ratelimit-reset-requests': '49.169s', 'x-ratelimit-reset-tokens': '109ms', 'x-request-id': 'req_63b7a2b5a962ad9b5d5cf91db126d21b', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba879aadd25994-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:31:44 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '5749', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9994', 'x-ratelimit-remaining-tokens': '199636', 'x-ratelimit-reset-requests': '49.169s', 'x-ratelimit-reset-tokens': '109ms', 'x-request-id': 'req_63b7a2b5a962ad9b5d5cf91db126d21b', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba879aadd25994-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_63b7a2b5a962ad9b5d5cf91db126d21b
# request_id: req_63b7a2b5a962ad9b5d5cf91db126d21b
# **********
# Trace: chat
#     |_agent_step -> 18.065115 seconds
#       |_llm -> 1.459862 seconds
#       |_function_call -> 2.400059 seconds
#       |_llm -> 0.844903 seconds
#       |_function_call -> 7.15396 seconds
#       |_llm -> 6.196315 seconds
# **********
# Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:
#
# 1. **Museums and Galleries**:
#    - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.
#    - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.
#
# 2. **Cultural Hubs**:
#    - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.
#
# 3. **Performing Arts**:
#    - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.
#
# 4. **Festivals**:
#    - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.
#
# 5. **Shopping and Dining**:
#    - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.
#
# Overall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.

# %%
response = agent.chat("Tell me about the history of Berlin")
print(str(response))
# Out:
# Added user message to memory: Tell me about the history of Berlin
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}, {'role': 'assistant', 'content': "Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:\n\n1. **Museums and Galleries**: \n   - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.\n   - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.\n\n2. **Cultural Hubs**: \n   - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\n3. **Performing Arts**: \n   - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.\n\n4. **Festivals**: \n   - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.\n\n5. **Shopping and Dining**: \n   - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors."}, {'role': 'user', 'content': 'Tell me about the history of Berlin'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'prop ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}, {'role': 'assistant', 'content': "Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:\n\n1. **Museums and Galleries**: \n   - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.\n   - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.\n\n2. **Cultural Hubs**: \n   - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\n3. **Performing Arts**: \n   - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.\n\n4. **Festivals**: \n   - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.\n\n5. **Shopping and Dining**: \n   - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors."}, {'role': 'user', 'content': 'Tell me about the history of Berlin'}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.0, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'sql_tool', 'description': 'Useful for translating a natural language query into a SQL query over a table containing: city_stats, containing the population/country of each city', 'parameters': {'properties': {'input': {'title ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E59BA0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E59BA0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C878F670>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C878F670>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:33:46 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'425'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'199292'), (b'x-ratelimit-reset-requests', b'8.64s'), (b'x-ratelimit-reset-tokens', b'212ms'), (b'x-request-id', b'req_411084ed6ce533226503df07d5754754'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8ab49dd05988-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:33:46 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'425'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'199292'), (b'x-ratelimit-reset-requests', b'8.64s'), (b'x-ratelimit-reset-tokens', b'212ms'), (b'x-request-id', b'req_411084ed6ce533226503df07d5754754'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8ab49dd05988-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:33:46 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '425', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9999', 'x-ratelimit-remaining-tokens': '199292', 'x-ratelimit-reset-requests': '8.64s', 'x-ratelimit-reset-tokens': '212ms', 'x-request-id': 'req_411084ed6ce533226503df07d5754754', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8ab49dd05988-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:33:46 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '425', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9999', 'x-ratelimit-remaining-tokens': '199292', 'x-ratelimit-reset-requests': '8.64s', 'x-ratelimit-reset-tokens': '212ms', 'x-request-id': 'req_411084ed6ce533226503df07d5754754', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8ab49dd05988-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_411084ed6ce533226503df07d5754754
# request_id: req_411084ed6ce533226503df07d5754754
# === Calling Function ===
# Calling function: vector_tool with args: {"input":"history of Berlin"}
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Your goal is to structure the user\'s query to match the request schema provided below.\n\n<< Structured Request Schema >>\nWhen responding use a markdown code snippet with a JSON object formatted in the following schema:\n\n{\'$defs\': {\'FilterOperator\': {\'description\': \'Vector store filter operator.\', \'enum\': [\'==\', \'>\', \'<\', \'!=\', \'>=\', \'<=\', \'in\', \'nin\', \'any\', \'all\', \'text_match\', \'contains\', \'is_empty\'], \'title\': \'FilterOperator\', \'type\': \'string\'}, \'MetadataFilter\': {\'description\': \'Comprehensive metadata filter for vector stores to support more operators.\\n\\nValue uses Strict* types, as int, float and str are compatible types and were all\\nconverted to string before.\\n\\nSee: https://docs.pydantic.dev/latest/usage/types/#strict-types\', \'properties\': {\'key\': {\'title\': \'Key\', \'type\': \'string\'}, \'value\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'number\'}, {\'type\': \'string\'}, {\'items\': {\'type\': \'string\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'number\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'integer\'}, \'type\': \'array\'}, {\'type\': \'null\'}], \'title\': \'Value\'}, \'operator\': {\'$ref\': \'#/$defs/FilterOperator\', \'default\': \'==\'}}, \'required\': [\'key\', \'value\'], \'title\': \'MetadataFilter\', \'type\': \'object\'}}, \'description\': \'Schema for a structured request for vector store\\n(i.e. to be converted to a VectorStoreQuery).\\n\\nCurrently only used by VectorIndexAutoRetriever.\', \'properties\': {\'query\': {\'title\': \'Query\', \'type\': \'string\'}, \'filters\': {\'items\': {\'$ref\': \'#/$defs/MetadataFilter\'}, \'title\': \'Filters\', \'type\': \'array\'}, \'top_k\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'null\'}], \'default\': None, \'title\': \'Top K\'}}, \'required\': [\'query\', \'filters\'], \'title\': \'VectorStoreQuerySpec\', \'type\': \'object\'}\n\nThe query string should contain only text that is expected to match the contents of documents. Any conditions in the filter should not be mentioned in the query as well.\n\nMake sure that filters only refer to attributes that exist in the data source.\nMake sure that filters take into account the descriptions of attributes.\nMake sure that filters are only used as needed. If there are no filters that should be applied return [] for the filter value.\nIf the user\'s query explicitly mentions number of documents to retrieve, set top_k to that number, otherwise do not set top_k.\n\n<< Example 1. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "artist",\n            "type": "str",\n            "description": "Name of the song artist"\n        }},\n        {{\n            "name": "genre",\n            "type": "str",\n            "description": "The song genre, one of \\"pop\\", \\"rock\\" or \\"rap\\""\n        }}\n    ],\n    "content_info": "Lyrics of a song"\n}}\n```\n\nUser Query:\nWhat are songs by Taylor Swift or Katy Perry in the dance pop genre\n\nStructured Request:\n```json\n{{"query":"teenager love","filters":[{{"key":"artist","value":"Taylor Swift","operator":"=="}},{{"key":"artist","value":"Katy Perry","operator":"=="}},{{"key":"genre","value":"pop","operator":"=="}}],"top_k":null}}\n\n\n<< Example 2. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "author",\n            "type": "str",\n            "description": "Author name"\n        }},\n        {{\n            "name": "book_title",\n            "type": "str",\n            "description": "Book title"\n        }},\n        {{\n            "name": "year",\n            "type": "int",\n            "description": "Year Published"\n        }},\n        {{\n            "name": "pages",\n            "type": "int",\n            "description": ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Your goal is to structure the user\'s query to match the request schema provided below.\n\n<< Structured Request Schema >>\nWhen responding use a markdown code snippet with a JSON object formatted in the following schema:\n\n{\'$defs\': {\'FilterOperator\': {\'description\': \'Vector store filter operator.\', \'enum\': [\'==\', \'>\', \'<\', \'!=\', \'>=\', \'<=\', \'in\', \'nin\', \'any\', \'all\', \'text_match\', \'contains\', \'is_empty\'], \'title\': \'FilterOperator\', \'type\': \'string\'}, \'MetadataFilter\': {\'description\': \'Comprehensive metadata filter for vector stores to support more operators.\\n\\nValue uses Strict* types, as int, float and str are compatible types and were all\\nconverted to string before.\\n\\nSee: https://docs.pydantic.dev/latest/usage/types/#strict-types\', \'properties\': {\'key\': {\'title\': \'Key\', \'type\': \'string\'}, \'value\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'number\'}, {\'type\': \'string\'}, {\'items\': {\'type\': \'string\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'number\'}, \'type\': \'array\'}, {\'items\': {\'type\': \'integer\'}, \'type\': \'array\'}, {\'type\': \'null\'}], \'title\': \'Value\'}, \'operator\': {\'$ref\': \'#/$defs/FilterOperator\', \'default\': \'==\'}}, \'required\': [\'key\', \'value\'], \'title\': \'MetadataFilter\', \'type\': \'object\'}}, \'description\': \'Schema for a structured request for vector store\\n(i.e. to be converted to a VectorStoreQuery).\\n\\nCurrently only used by VectorIndexAutoRetriever.\', \'properties\': {\'query\': {\'title\': \'Query\', \'type\': \'string\'}, \'filters\': {\'items\': {\'$ref\': \'#/$defs/MetadataFilter\'}, \'title\': \'Filters\', \'type\': \'array\'}, \'top_k\': {\'anyOf\': [{\'type\': \'integer\'}, {\'type\': \'null\'}], \'default\': None, \'title\': \'Top K\'}}, \'required\': [\'query\', \'filters\'], \'title\': \'VectorStoreQuerySpec\', \'type\': \'object\'}\n\nThe query string should contain only text that is expected to match the contents of documents. Any conditions in the filter should not be mentioned in the query as well.\n\nMake sure that filters only refer to attributes that exist in the data source.\nMake sure that filters take into account the descriptions of attributes.\nMake sure that filters are only used as needed. If there are no filters that should be applied return [] for the filter value.\nIf the user\'s query explicitly mentions number of documents to retrieve, set top_k to that number, otherwise do not set top_k.\n\n<< Example 1. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "artist",\n            "type": "str",\n            "description": "Name of the song artist"\n        }},\n        {{\n            "name": "genre",\n            "type": "str",\n            "description": "The song genre, one of \\"pop\\", \\"rock\\" or \\"rap\\""\n        }}\n    ],\n    "content_info": "Lyrics of a song"\n}}\n```\n\nUser Query:\nWhat are songs by Taylor Swift or Katy Perry in the dance pop genre\n\nStructured Request:\n```json\n{{"query":"teenager love","filters":[{{"key":"artist","value":"Taylor Swift","operator":"=="}},{{"key":"artist","value":"Katy Perry","operator":"=="}},{{"key":"genre","value":"pop","operator":"=="}}],"top_k":null}}\n\n\n<< Example 2. >>\nData Source:\n```json\n{{\n    "metadata_info": [\n        {{\n            "name": "author",\n            "type": "str",\n            "description": "Author name"\n        }},\n        {{\n            "name": "book_title",\n            "type": "str",\n            "description": "Book title"\n        }},\n        {{\n            "name": "year",\n            "type": "int",\n            "description": "Year Published"\n        }},\n        {{\n            "name": "pages",\n            "type": "int",\n            "description": "Number of pages"\n       ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9EAB6D0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9EAB6D0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C9E498C0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C9E498C0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C85BDDE0>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C85BDDE0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:33:47 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'601'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'198872'), (b'x-ratelimit-reset-requests', b'16.408s'), (b'x-ratelimit-reset-tokens', b'338ms'), (b'x-request-id', b'req_690009a766573c9f73bdf33b8c95ac5a'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8ab9fc3b5a11-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:33:47 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'601'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'198872'), (b'x-ratelimit-reset-requests', b'16.408s'), (b'x-ratelimit-reset-tokens', b'338ms'), (b'x-request-id', b'req_690009a766573c9f73bdf33b8c95ac5a'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8ab9fc3b5a11-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:33:47 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '601', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9998', 'x-ratelimit-remaining-tokens': '198872', 'x-ratelimit-reset-requests': '16.408s', 'x-ratelimit-reset-tokens': '338ms', 'x-request-id': 'req_690009a766573c9f73bdf33b8c95ac5a', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8ab9fc3b5a11-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:33:47 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '601', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9998', 'x-ratelimit-remaining-tokens': '198872', 'x-ratelimit-reset-requests': '16.408s', 'x-ratelimit-reset-tokens': '338ms', 'x-request-id': 'req_690009a766573c9f73bdf33b8c95ac5a', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8ab9fc3b5a11-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_690009a766573c9f73bdf33b8c95ac5a
# request_id: req_690009a766573c9f73bdf33b8c95ac5a
# INFO:llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever:Using query str: history of Berlin
# Using query str: history of Berlin
# INFO:llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever:Using filters: []
# Using filters: []
# INFO:llama_index.core.indices.vector_store.retrievers.auto_retriever.auto_retriever:Using top_k: 2
# Using top_k: 2
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C9BF3D00>, 'json_data': {'input': ['history of Berlin'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x00000180C9BF3D00>, 'json_data': {'input': ['history of Berlin'], 'model': 'text-embedding-3-small', 'encoding_format': 'base64'}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7EF50>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7EF50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C53F3D40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9EA8700>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9EA8700>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:33:48 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'136'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999996'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_b65bc2042017c2c4b906f8f410b20ca0'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8ac03c41550b-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:33:48 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-small'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'136'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'3000'), (b'x-ratelimit-limit-tokens', b'1000000'), (b'x-ratelimit-remaining-requests', b'2999'), (b'x-ratelimit-remaining-tokens', b'999996'), (b'x-ratelimit-reset-requests', b'20ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_b65bc2042017c2c4b906f8f410b20ca0'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8ac03c41550b-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:33:48 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '136', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999996', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_b65bc2042017c2c4b906f8f410b20ca0', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8ac03c41550b-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:33:48 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-small', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '136', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999996', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_b65bc2042017c2c4b906f8f410b20ca0', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8ac03c41550b-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_b65bc2042017c2c4b906f8f410b20ca0
# request_id: req_b65bc2042017c2c4b906f8f410b20ca0
# DEBUG:pinecone.core.openapi.shared.rest:response body: b'{"results":[],"matches":[{"id":"23765c7d-fda1-40e4-b123-ec6468a672d5","score":0.606785774,"values":[0.0105627384,0.00599226588,0.0544072874,0.00829379354,-0.029573299,0.0239335187,-0.0268718917,0.0309713949,-0.038672775,0.0426537953,0.0312794484,-0.0115342969,0.0365637802,-0.0227131452,0.013068649,-0.0289571881,-0.0108589455,0.0485779345,0.00184092601,0.0398813,0.0179619864,0.00484594516,-0.0351656862,-0.00579973124,-0.00263031735,0.0379855745,-0.00867886283,-0.0123222079,-0
yo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}, {'role': 'assistant', 'content': "Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:\n\n1. **Museums and Galleries**: \n   - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.\n   - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.\n\n2. **Cultural Hubs**: \n   - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\n3. **Performing Arts**: \n   - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.\n\n4. **Festivals**: \n   - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.\n\n5. **Shopping and Dining**: \n   - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors."}, {'role': 'user', 'content': 'Tell me about the history of Berlin'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_5TCmusOHsiKmDCFiMC3NMdCK', 'function': {'arguments': '{"input":"history of Berlin"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Berlin\'s history dates back to prehistoric times, with the earliest human settlements in the area around 60,000 BC. The Maglemosian  ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5A1D0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5A1D0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C89FBE40> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5A440>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E5A440>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:12 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'11861'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9997'), (b'x-ratelimit-remaining-tokens', b'198706'), (b'x-ratelimit-reset-requests', b'20.256s'), (b'x-ratelimit-reset-tokens', b'387ms'), (b'x-request-id', b'req_f09d792d262b4c4837d4d0a7a3fb1394'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b0e193e598e-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:12 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'11861'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9997'), (b'x-ratelimit-remaining-tokens', b'198706'), (b'x-ratelimit-reset-requests', b'20.256s'), (b'x-ratelimit-reset-tokens', b'387ms'), (b'x-request-id', b'req_f09d792d262b4c4837d4d0a7a3fb1394'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b0e193e598e-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:12 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '11861', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9997', 'x-ratelimit-remaining-tokens': '198706', 'x-ratelimit-reset-requests': '20.256s', 'x-ratelimit-reset-tokens': '387ms', 'x-request-id': 'req_f09d792d262b4c4837d4d0a7a3fb1394', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b0e193e598e-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:12 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '11861', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9997', 'x-ratelimit-remaining-tokens': '198706', 'x-ratelimit-reset-requests': '20.256s', 'x-ratelimit-reset-tokens': '387ms', 'x-request-id': 'req_f09d792d262b4c4837d4d0a7a3fb1394', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b0e193e598e-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_f09d792d262b4c4837d4d0a7a3fb1394
# request_id: req_f09d792d262b4c4837d4d0a7a3fb1394
# **********
# Trace: chat
#     |_agent_step -> 26.666201 seconds
#       |_llm -> 0.89558 seconds
#       |_function_call -> 13.453446 seconds
#       |_llm -> 12.30618 seconds
# **********
# Berlin's history is rich and complex, dating back to prehistoric times. Here are some key points in its historical timeline:
#
# 1. **Prehistoric Settlements**: The earliest human settlements in the Berlin area date back to around 60,000 BC, with evidence of the Maglemosian culture around 9,000 BC. By 2,000 BC, dense settlements along the Spree and Havel rivers led to the emergence of the Lusatian culture.
#
# 2. **Tribal Settlements**: Germanic tribes began settling in the region around 500 BC, followed by Slavic tribes in the 7th century.
#
# 3. **German Rule**: In the 12th century, the area came under German rule as part of the Margraviate of Brandenburg, established by Albert the Bear in 1157. The first written records of towns in present-day Berlin appear in the late 12th century, with Spandau mentioned in 1197 and Köpenick in 1209. The city is considered to have been founded in 1237, with the towns of Berlin and Cölln forming close economic ties.
#
# 4. **Hohenzollern Dynasty**: The Hohenzollern family ruled Berlin from the late 12th century until 1918, initially as electors of Brandenburg and later as kings of Prussia and German emperors. The construction of a royal palace began in 1443, and by 1539, the city had officially adopted Lutheranism.
#
# 5. **Thirty Years' War**: The Thirty Years' War (1618-1648) devastated Berlin, leading to significant population loss. Frederick William, known as the "Great Elector," promoted immigration and religious tolerance, notably offering asylum to French Huguenots in 1685. By 1700, a significant portion of Berlin's population was of French descent.
#
# 6. **Kingdom of Prussia**: In 1701, the Margraviate of Brandenburg and the Duchy of Prussia united to form the Kingdom of Prussia, with Berlin as its capital. The city experienced growth and became a center of the Enlightenment under Frederick II (Frederick the Great).
#
# 7. **Industrial Revolution**: The Industrial Revolution in the 19th century transformed Berlin into a major economic hub, leading to rapid population growth and the incorporation of surrounding suburbs.
#
# 8. **20th Century**: Berlin became the capital of the newly founded German Empire in 1871. After World War II, the city was divided into East and West Berlin, with East Berlin serving as the capital of East Germany.
#
# 9. **Reunification**: Following the reunification of Germany in 1990, Berlin regained its status as the capital of a unified Germany.
#
# Today, Berlin is known for its rich history, cultural significance, and diverse economy, serving as a major European hub for various industries and tourism.

# %%
response = agent.chat(
    "Can you give me the country corresponding to each city?"
)
print(str(response))
# Out:
# Added user message to memory: Can you give me the country corresponding to each city?
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}, {'role': 'assistant', 'content': "Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:\n\n1. **Museums and Galleries**: \n   - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.\n   - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.\n\n2. **Cultural Hubs**: \n   - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\n3. **Performing Arts**: \n   - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.\n\n4. **Festivals**: \n   - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.\n\n5. **Shopping and Dining**: \n   - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors."}, {'role': 'user', 'content': 'Tell me about the history of Berlin'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_5TCmusOHsiKmDCFiMC3NMdCK', 'function': {'arguments': '{"input":"history of Berlin"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Berlin\'s history dates back to prehistoric times, with the earliest human settlements in the area around 6 ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}, {'role': 'assistant', 'content': "Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:\n\n1. **Museums and Galleries**: \n   - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.\n   - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.\n\n2. **Cultural Hubs**: \n   - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\n3. **Performing Arts**: \n   - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.\n\n4. **Festivals**: \n   - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.\n\n5. **Shopping and Dining**: \n   - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors."}, {'role': 'user', 'content': 'Tell me about the history of Berlin'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_5TCmusOHsiKmDCFiMC3NMdCK', 'function': {'arguments': '{"input":"history of Berlin"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Berlin\'s history dates back to prehistoric times, with the earliest human settlements in the area around 60,000 BC. The Maglemosian  ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:13 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'516'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'198043'), (b'x-ratelimit-reset-requests', b'16.557s'), (b'x-ratelimit-reset-tokens', b'587ms'), (b'x-request-id', b'req_c94ef1b0303c272069e63ad0fd887072'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b5b1ec6598e-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:13 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'516'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9998'), (b'x-ratelimit-remaining-tokens', b'198043'), (b'x-ratelimit-reset-requests', b'16.557s'), (b'x-ratelimit-reset-tokens', b'587ms'), (b'x-request-id', b'req_c94ef1b0303c272069e63ad0fd887072'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b5b1ec6598e-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:13 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '516', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9998', 'x-ratelimit-remaining-tokens': '198043', 'x-ratelimit-reset-requests': '16.557s', 'x-ratelimit-reset-tokens': '587ms', 'x-request-id': 'req_c94ef1b0303c272069e63ad0fd887072', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b5b1ec6598e-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:13 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '516', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9998', 'x-ratelimit-remaining-tokens': '198043', 'x-ratelimit-reset-requests': '16.557s', 'x-ratelimit-reset-tokens': '587ms', 'x-request-id': 'req_c94ef1b0303c272069e63ad0fd887072', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b5b1ec6598e-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_c94ef1b0303c272069e63ad0fd887072
# request_id: req_c94ef1b0303c272069e63ad0fd887072
# === Calling Function ===
# Calling function: sql_tool with args: {"input":"SELECT city, country FROM city_stats;"}
# INFO:llama_index.core.indices.struct_store.sql_retriever:> Table desc str: Table 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .
# > Table desc str: Table 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, first create a syntactically correct sqlite query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return the most interesting examples in the database.\n\nNever query for all the columns from a specific table, only ask for a few relevant columns given the question.\n\nPay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Pay attention to which column is in which table. Also, qualify column names with the table name when needed. You are required to use the following format, each taking one line:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use tables listed below.\nTable 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .\n\nQuestion: SELECT city, country FROM city_stats;\nSQLQuery: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, first create a syntactically correct sqlite query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return the most interesting examples in the database.\n\nNever query for all the columns from a specific table, only ask for a few relevant columns given the question.\n\nPay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Pay attention to which column is in which table. Also, qualify column names with the table name when needed. You are required to use the following format, each taking one line:\n\nQuestion: Question here\nSQLQuery: SQL Query to run\nSQLResult: Result of the SQLQuery\nAnswer: Final answer here\n\nOnly use tables listed below.\nTable 'city_stats' has columns: city_name (VARCHAR(16)), population (INTEGER), country (VARCHAR(16)), .\n\nQuestion: SELECT city, country FROM city_stats;\nSQLQuery: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7E260>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9E7E260>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# start_tls.started ssl_context=<ssl.SSLContext object at 0x00000180C84751C0> server_hostname='api.openai.com' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9EABD00>
# start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000180C9EABD00>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:14 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'703'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9997'), (b'x-ratelimit-remaining-tokens', b'199736'), (b'x-ratelimit-reset-requests', b'24.228s'), (b'x-ratelimit-reset-tokens', b'79ms'), (b'x-request-id', b'req_5feca9cdc92595f585f67accc91b1233'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b613e3359a2-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:14 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'703'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9997'), (b'x-ratelimit-remaining-tokens', b'199736'), (b'x-ratelimit-reset-requests', b'24.228s'), (b'x-ratelimit-reset-tokens', b'79ms'), (b'x-request-id', b'req_5feca9cdc92595f585f67accc91b1233'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b613e3359a2-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:14 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '703', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9997', 'x-ratelimit-remaining-tokens': '199736', 'x-ratelimit-reset-requests': '24.228s', 'x-ratelimit-reset-tokens': '79ms', 'x-request-id': 'req_5feca9cdc92595f585f67accc91b1233', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b613e3359a2-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:14 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '703', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9997', 'x-ratelimit-remaining-tokens': '199736', 'x-ratelimit-reset-requests': '24.228s', 'x-ratelimit-reset-tokens': '79ms', 'x-request-id': 'req_5feca9cdc92595f585f67accc91b1233', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b613e3359a2-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_5feca9cdc92595f585f67accc91b1233
# request_id: req_5feca9cdc92595f585f67accc91b1233
# DEBUG:llama_index.core.indices.struct_store.sql_retriever:> Predicted SQL query: SELECT city_name, country FROM city_stats;
# > Predicted SQL query: SELECT city_name, country FROM city_stats;
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, synthesize a response from the query results.\nQuery: SELECT city, country FROM city_stats;\nSQL: SELECT city_name, country FROM city_stats;\nSQL Response: [('Toronto', 'Canada'), ('Tokyo', 'Japan'), ('Berlin', 'Germany')]\nResponse: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': "Given an input question, synthesize a response from the query results.\nQuery: SELECT city, country FROM city_stats;\nSQL: SELECT city_name, country FROM city_stats;\nSQL Response: [('Toronto', 'Canada'), ('Tokyo', 'Japan'), ('Berlin', 'Germany')]\nResponse: "}], 'model': 'gpt-4o-mini', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:15 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'621'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9996'), (b'x-ratelimit-remaining-tokens', b'199918'), (b'x-ratelimit-reset-requests', b'31.776s'), (b'x-ratelimit-reset-tokens', b'24ms'), (b'x-request-id', b'req_b150e2e88504893b76c1fa2c18899cc8'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b6809d559a2-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:15 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'621'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9996'), (b'x-ratelimit-remaining-tokens', b'199918'), (b'x-ratelimit-reset-requests', b'31.776s'), (b'x-ratelimit-reset-tokens', b'24ms'), (b'x-request-id', b'req_b150e2e88504893b76c1fa2c18899cc8'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b6809d559a2-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:15 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '621', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9996', 'x-ratelimit-remaining-tokens': '199918', 'x-ratelimit-reset-requests': '31.776s', 'x-ratelimit-reset-tokens': '24ms', 'x-request-id': 'req_b150e2e88504893b76c1fa2c18899cc8', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b6809d559a2-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:15 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '621', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9996', 'x-ratelimit-remaining-tokens': '199918', 'x-ratelimit-reset-requests': '31.776s', 'x-ratelimit-reset-tokens': '24ms', 'x-request-id': 'req_b150e2e88504893b76c1fa2c18899cc8', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b6809d559a2-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_b150e2e88504893b76c1fa2c18899cc8
# request_id: req_b150e2e88504893b76c1fa2c18899cc8
# Got output: The cities and their corresponding countries from the query results are as follows: Toronto in Canada, Tokyo in Japan, and Berlin in Germany.
# ========================
#
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}, {'role': 'assistant', 'content': "Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:\n\n1. **Museums and Galleries**: \n   - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.\n   - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.\n\n2. **Cultural Hubs**: \n   - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\n3. **Performing Arts**: \n   - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.\n\n4. **Festivals**: \n   - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.\n\n5. **Shopping and Dining**: \n   - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors."}, {'role': 'user', 'content': 'Tell me about the history of Berlin'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_5TCmusOHsiKmDCFiMC3NMdCK', 'function': {'arguments': '{"input":"history of Berlin"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Berlin\'s history dates back to prehistoric times, with the earliest human settlements in the area around 6 ...
# Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': 'Tell me about the arts and culture of the city with the highest population'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh', 'function': {'arguments': '{"input":"SELECT city, population FROM city_stats ORDER BY population DESC LIMIT 1;"}', 'name': 'sql_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'The city with the highest population is Tokyo, which has a population of 13,960,000.', 'name': 'sql_tool', 'tool_call_id': 'call_YxFkQKiQu3UXOKQsMUn4lyoh'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_toJOhHqvmWkO8FwyobT1eQjQ', 'function': {'arguments': '{"input":"arts and culture of Tokyo"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': "Tokyo boasts a rich and diverse arts and culture scene, featuring numerous museums, galleries, and performance venues. The city is home to significant institutions such as the Tokyo National Museum, which specializes in traditional Japanese art, and the National Museum of Western Art, recognized for its architectural significance. Ueno Park is a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\nArt galleries like the Nezu Museum focus on pre-modern Japanese and East Asian art, while contemporary art is showcased at the Mori Art Museum in Roppongi. The city also celebrates its cultural heritage through traditional performing arts at venues like the National Noh Theatre and Kabuki-za.\n\nTokyo's vibrant cultural landscape is further enriched by its festivals, such as the Sannō Matsuri and the Sanja Festival, which feature elaborate parades and traditional performances. The city's shopping districts, like Ginza and Nihombashi, blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors.", 'name': 'vector_tool', 'tool_call_id': 'call_toJOhHqvmWkO8FwyobT1eQjQ'}, {'role': 'assistant', 'content': "Tokyo, the city with the highest population (approximately 13,960,000), boasts a rich and diverse arts and culture scene. Here are some highlights:\n\n1. **Museums and Galleries**: \n   - The **Tokyo National Museum** specializes in traditional Japanese art, while the **National Museum of Western Art** is noted for its architectural significance.\n   - The **Nezu Museum** focuses on pre-modern Japanese and East Asian art, and contemporary art is showcased at the **Mori Art Museum** in Roppongi.\n\n2. **Cultural Hubs**: \n   - **Ueno Park** serves as a cultural hub, housing multiple museums and a zoo known for its giant pandas.\n\n3. **Performing Arts**: \n   - Traditional performing arts are celebrated at venues like the **National Noh Theatre** and **Kabuki-za**, where audiences can experience classic Japanese theater.\n\n4. **Festivals**: \n   - Tokyo hosts vibrant festivals such as the **Sannō Matsuri** and the **Sanja Festival**, featuring elaborate parades and traditional performances.\n\n5. **Shopping and Dining**: \n   - Shopping districts like **Ginza** and **Nihombashi** blend commerce with culture, offering luxury shopping alongside art galleries and fine dining.\n\nOverall, Tokyo's arts and culture reflect a harmonious blend of tradition and modernity, making it a dynamic destination for both residents and visitors."}, {'role': 'user', 'content': 'Tell me about the history of Berlin'}, {'role': 'assistant', 'content': None, 'tool_calls': [{'id': 'call_5TCmusOHsiKmDCFiMC3NMdCK', 'function': {'arguments': '{"input":"history of Berlin"}', 'name': 'vector_tool'}, 'type': 'function'}]}, {'role': 'tool', 'content': 'Berlin\'s history dates back to prehistoric times, with the earliest human settlements in the area around 60,000 BC. The Maglemosian  ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:16 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'622'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9995'), (b'x-ratelimit-remaining-tokens', b'198006'), (b'x-ratelimit-reset-requests', b'39.373s'), (b'x-ratelimit-reset-tokens', b'598ms'), (b'x-request-id', b'req_202b57dc07598b9a3a87fd7f4a67dbcd'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b6e7a17598e-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 01 Nov 2024 08:34:16 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-f8xnqrzkrmt0qbpgbtsecvpc'), (b'openai-processing-ms', b'622'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9995'), (b'x-ratelimit-remaining-tokens', b'198006'), (b'x-ratelimit-reset-requests', b'39.373s'), (b'x-ratelimit-reset-tokens', b'598ms'), (b'x-request-id', b'req_202b57dc07598b9a3a87fd7f4a67dbcd'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8dba8b6e7a17598e-DEL'), (b'Content-Encoding', b'gzip'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:16 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '622', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9995', 'x-ratelimit-remaining-tokens': '198006', 'x-ratelimit-reset-requests': '39.373s', 'x-ratelimit-reset-tokens': '598ms', 'x-request-id': 'req_202b57dc07598b9a3a87fd7f4a67dbcd', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b6e7a17598e-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Fri, 01 Nov 2024 08:34:16 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-f8xnqrzkrmt0qbpgbtsecvpc', 'openai-processing-ms': '622', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '9995', 'x-ratelimit-remaining-tokens': '198006', 'x-ratelimit-reset-requests': '39.373s', 'x-ratelimit-reset-tokens': '598ms', 'x-request-id': 'req_202b57dc07598b9a3a87fd7f4a67dbcd', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '8dba8b6e7a17598e-DEL', 'content-encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'})
# DEBUG:openai._base_client:request_id: req_202b57dc07598b9a3a87fd7f4a67dbcd
# request_id: req_202b57dc07598b9a3a87fd7f4a67dbcd
# **********
# Trace: chat
#     |_agent_step -> 4.137324 seconds
#       |_llm -> 0.935139 seconds
#       |_function_call -> 2.148843 seconds
#       |_llm -> 1.039348 seconds
# **********
# Here are the cities along with their corresponding countries:
#
# - **Toronto** - Canada
# - **Tokyo** - Japan
# - **Berlin** - Germany
